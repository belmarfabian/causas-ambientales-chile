# %%
from __future__ import annotations

import csv
import hashlib
import time
from typing import Dict, List, Set
from urllib.parse import urljoin, urlparse

import requests
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET

# -----------------------------
# Configuración
# -----------------------------
BASE = "https://tribunalambiental.cl/"
SITEMAP_INDEX = urljoin(BASE, "wp-sitemap.xml")

KEYWORDS = [
    "sentencia", "sentencias",
    "informe", "informes",
    "expediente", "causa",
    "rol", "rit",
    "resolucion", "fallo",
]

MAX_TARGET_URLS = 600
SLEEP_SECONDS = 1.0
TIMEOUT = 25

OUT_CSV = "/content/tribunalambiental_consolidado.csv"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122 Safari/537.36",
    "Accept-Language": "es-CL,es;q=0.9,en;q=0.8",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
}

# -----------------------------
# Helpers
# -----------------------------
def _domain(url: str) -> str:
    return urlparse(url).netloc.lower()

def _same_domain(url: str, base: str) -> bool:
    return _domain(url) == _domain(base)

def fetch(session: requests.Session, url: str) -> requests.Response:
    r = session.get(url, headers=HEADERS, timeout=TIMEOUT, allow_redirects=True)
    r.raise_for_status()
    return r

def parse_sitemap_locs(xml_text: str) -> List[str]:
    root = ET.fromstring(xml_text)
    ns = {"sm": root.tag.split("}")[0].strip("{")} if "}" in root.tag else {}

    locs: List[str] = []

    # sitemap index
    for loc in root.findall(".//sm:sitemap/sm:loc", ns) + root.findall(".//sitemap/loc"):
        if loc.text:
            locs.append(loc.text.strip())

    # urlset
    for loc in root.findall(".//sm:url/sm:loc", ns) + root.findall(".//url/loc"):
        if loc.text:
            locs.append(loc.text.strip())

    # dedup conservando orden
    seen: Set[str] = set()
    out: List[str] = []
    for u in locs:
        if u and u not in seen:
            out.append(u)
            seen.add(u)
    return out

def keyword_hit(url: str) -> bool:
    u = url.lower()
    return any(k in u for k in KEYWORDS)

def extract_pdf_links_from_tag(tag, page_url: str) -> List[str]:
    pdfs: List[str] = []
    for a in tag.find_all("a", href=True):
        href = a.get("href", "").strip()
        if not href:
            continue
        absu = urljoin(page_url, href)
        if absu.lower().endswith(".pdf"):
            pdfs.append(absu)
    # dedup
    seen: Set[str] = set()
    out: List[str] = []
    for p in pdfs:
        if p not in seen:
            out.append(p)
            seen.add(p)
    return out

def extract_page_pdf_links(soup: BeautifulSoup, page_url: str) -> List[str]:
    pdfs: List[str] = []
    for a in soup.find_all("a", href=True):
        href = a.get("href", "").strip()
        if not href:
            continue
        absu = urljoin(page_url, href)
        if absu.lower().endswith(".pdf"):
            pdfs.append(absu)
    # dedup
    seen: Set[str] = set()
    out: List[str] = []
    for p in pdfs:
        if p not in seen:
            out.append(p)
            seen.add(p)
    return out

def extract_table_records(soup: BeautifulSoup, page_url: str, page_title: str) -> List[Dict[str, str]]:
    records: List[Dict[str, str]] = []
    tables = soup.find_all("table")

    for ti, table in enumerate(tables, start=1):
        headers: List[str] = []
        thead_th = table.select("thead th")
        if thead_th:
            headers = [th.get_text(" ", strip=True) for th in thead_th]
        else:
            first_tr = table.find("tr")
            if first_tr:
                ths = first_tr.find_all("th")
                if ths:
                    headers = [th.get_text(" ", strip=True) for th in ths]

        row_index = 0
        for tr in table.find_all("tr"):
            tds = tr.find_all("td")
            if not tds:
                continue
            row_index += 1
            cells = [td.get_text(" ", strip=True) for td in tds]
            if not headers:
                headers = [f"col_{i+1}" for i in range(len(cells))]

            rec: Dict[str, str] = {
                "page_url": page_url,
                "page_title": page_title,
                "table_index": str(ti),
                "row_index": str(row_index),
            }

            for i, h in enumerate(headers):
                key = h.strip() if h and h.strip() else f"col_{i+1}"
                rec[key] = cells[i] if i < len(cells) else ""

            pdfs_row = extract_pdf_links_from_tag(tr, page_url)
            rec["pdf_links_row"] = " | ".join(pdfs_row)
            records.append(rec)

    return records

def record_key(rec: Dict[str, str]) -> str:
    base = [rec.get("page_url", ""), rec.get("table_index", ""), rec.get("row_index", "")]
    extra_items = sorted((k, v) for k, v in rec.items() if k not in ("pdf_links_row", "pdf_links_page"))
    payload = "|".join(base) + "||" + "|".join(f"{k}={v}" for k, v in extra_items)
    return hashlib.sha1(payload.encode("utf-8", errors="ignore")).hexdigest()

# -----------------------------
# Main
# -----------------------------
print("== Batch scrape tribunalambiental.cl (WP sitemap) ==")
print("Sitemap index:", SITEMAP_INDEX)

all_records: List[Dict[str, str]] = []
seen_rec: Set[str] = set()

with requests.Session() as session:
    # 1) sitemap index
    r = fetch(session, SITEMAP_INDEX)
    child_sitemaps = [u for u in parse_sitemap_locs(r.text) if u.lower().endswith(".xml")]
    print("Child sitemaps:", len(child_sitemaps))
    for u in child_sitemaps:
        print(" -", u)

    # 2) bajar sitemaps hijos y juntar URLs
    all_urls: List[str] = []
    for i, sm in enumerate(child_sitemaps, start=1):
        time.sleep(SLEEP_SECONDS)
        try:
            rs = fetch(session, sm)
            locs = parse_sitemap_locs(rs.text)
            locs = [u for u in locs if _same_domain(u, BASE)]
            all_urls.extend(locs)
            print(f"[sitemap {i}/{len(child_sitemaps)}] locs={len(locs)} -> {sm}")
        except Exception as e:
            print("[WARN] fallo leyendo sitemap:", sm, "|", e)

    # dedup URLs
    seen_url: Set[str] = set()
    uniq_urls: List[str] = []
    for u in all_urls:
        if u not in seen_url:
            uniq_urls.append(u)
            seen_url.add(u)

    print("Total URLs (dedup):", len(uniq_urls))

    # 3) filtrar targets por keywords en URL
    targets = [u for u in uniq_urls if keyword_hit(u)]
    print("Targets por keywords:", len(targets))

    if len(targets) > MAX_TARGET_URLS:
        print(f"[INFO] recortando targets a MAX_TARGET_URLS={MAX_TARGET_URLS}")
        targets = targets[:MAX_TARGET_URLS]

    # 4) scrape por cada target
    for idx, url in enumerate(targets, start=1):
        time.sleep(SLEEP_SECONDS)
        try:
            rp = fetch(session, url)
            soup = BeautifulSoup(rp.text, "html.parser")
            title = soup.title.get_text(" ", strip=True) if soup.title else ""

            page_recs = extract_table_records(soup, rp.url, title)
            page_pdfs = extract_page_pdf_links(soup, rp.url)
            page_pdfs_join = " | ".join(page_pdfs)

            # placeholder si no hay tablas
            if not page_recs:
                page_recs = [{
                    "page_url": rp.url,
                    "page_title": title,
                    "table_index": "",
                    "row_index": "",
                    "pdf_links_row": "",
                }]

            for rec in page_recs:
                rec["pdf_links_page"] = page_pdfs_join
                k = record_key(rec)
                if k not in seen_rec:
                    all_records.append(rec)
                    seen_rec.add(k)

            print(f"[{idx}/{len(targets)}] OK rows={len(page_recs)} pdfs_page={len(page_pdfs)} | {rp.url}")

        except Exception as e:
            print("[WARN] fallo:", url, "|", e)

# 5) export CSV con columnas dinámicas
if not all_records:
    raise RuntimeError("No se extrajeron registros. Ajusta KEYWORDS o revisa conectividad.")

cols: Set[str] = set()
for rec in all_records:
    cols.update(rec.keys())

preferred = ["page_url", "page_title", "table_index", "row_index", "pdf_links_row", "pdf_links_page"]
rest = sorted([c for c in cols if c not in preferred])
fieldnames = preferred + rest

with open(OUT_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.DictWriter(f, fieldnames=fieldnames)
    w.writeheader()
    for rec in all_records:
        w.writerow(rec)

print("\n== Listo ==")
print("Registros (dedup):", len(all_records))
print("CSV:", OUT_CSV)
# Out:
# == Batch scrape tribunalambiental.cl (WP sitemap) ==
# Sitemap index: https://tribunalambiental.cl/wp-sitemap.xml
# Child sitemaps: 6
#  - https://tribunalambiental.cl/wp-sitemap-posts-post-1.xml
#  - https://tribunalambiental.cl/wp-sitemap-posts-post-2.xml
#  - https://tribunalambiental.cl/wp-sitemap-posts-page-1.xml
#  - https://tribunalambiental.cl/wp-sitemap-taxonomies-category-1.xml
#  - https://tribunalambiental.cl/wp-sitemap-taxonomies-post_tag-1.xml
#  - https://tribunalambiental.cl/wp-sitemap-taxonomies-post_format-1.xml
# [sitemap 1/6] locs=2000 -> https://tribunalambiental.cl/wp-sitemap-posts-post-1.xml
# [sitemap 2/6] locs=33 -> https://tribunalambiental.cl/wp-sitemap-posts-post-2.xml
# [sitemap 3/6] locs=51 -> https://tribunalambiental.cl/wp-sitemap-posts-page-1.xml
# [sitemap 4/6] locs=31 -> https://tribunalambiental.cl/wp-sitemap-taxonomies-category-1.xml
# [sitemap 5/6] locs=1 -> https://tribunalambiental.cl/wp-sitemap-taxonomies-post_tag-1.xml
# [sitemap 6/6] locs=2 -> https://tribunalambiental.cl/wp-sitemap-taxonomies-post_format-1.xml
# Total URLs (dedup): 2116
# Targets por keywords: 285
# [1/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-dicto-su-primer-fallo/
# [2/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/palabras-del-ministro-haroldo-brito-durante-inauguracion-de-dependencias-del-tribunal/
# [3/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/corte-de-apelaciones-de-santiago-rechaza-recurso-interpuesto-por-la-sma-contra-sentencia-del-tribunal-ambiental/
# [4/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-realizo-audiencia-en-causa-por-ruidos-molestos-en-construccion/
# [5/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-escucho-alegatos-contra-resolucion-de-la-sma-que-obliga-a-santiago-down-town-a-ingresar-a-evaluacion-ambiental/
# [6/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-ordena-a-la-sma-rehacer-resolucion-sancionatoria-a-pascua-lama/
# [7/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-realizara-su-primera-audiencia-de-expertos-en-causa-contra-el-ministerio-del-medio-ambiente-por-modificacion-de-norma-de-mp10/
# [8/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/expertos-entregaron-su-testimonio-ante-tribunal-ambiental-en-causa-por-modificacion-de-norma-pm10/
# [9/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/admite-a-tramite-eclamacion-de-la-corporacion-privada-para-el-desarrollo-de-aysen-contra-el-director-nacional-del-sernageomin-res-ex-n0448/
# [10/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-de-santiago-ordeno-acumulacion-de-causas-interpuestas-por-hidroaysen/
# [11/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/primera-sentencia-en-demanda-por-dano-ambiental-en-el-pais-tribunal-ambiental-de-santiago-condeno-a-empresa-a-reparar-medio-ambiente-danado/
# [12/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/audiencia-causa-r-48-2014-reclamacion-de-agricola-el-sol-de-copiapo-ltda-contra-la-sma-por-resolucion-n-1223-23-9-2014/
# [13/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/corte-suprema-rechazo-recursos-de-casacion-de-sqm-contra-sentencia-del-tribunal-ambiental-de-santiago/
# [14/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/corte-suprema-rechazo-casacion-contra-sentencia-del-tribunal-ambiental-en-caso-proyecto-piscicultura-rio-calcurrupe/
# [15/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/jueves-28-a-las-1500-hrs-audiencia-en-reclamacion-de-enap-contra-fiscal-maritimo-en-caso-derrame-de-petroleo-en-bahia-de-quintero/
# [16/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/anuario-214-tribunal-ambiental-dicto-22-sentencias/
# [17/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-admitio-a-tramite-reclamacion-de-trabajadores-del-mar-de-ventanas-y-horcon-contra-la-sma-por-derrame-de-petroleo-en-quintero/
# [18/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/alegatos-de-la-causa-r-76-2015-se-realizaran-este-jueves-1-de-octubre-a-las-1500-horas/
# [19/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/rechazo-casacion-corte-suprema-confirmo-fallo-del-tribunal-ambiental-que-anulo-modificacion-a-norma-de-material-particulado-mp10/
# [20/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/catedratico-espanol-jordi-nieva-dialogo-con-miembros-del-tribunal-ambiental-acerca-de-la-sana-critica/
# [21/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/en-el-marco-del-convenio-de-colaboracion-suscrito-con-el-centro-de-derecho-ambiental-de-la-universidad-de-chile-cierre-de-postulacion-30-de-octubre/
# [22/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/dictada-por-funcionario-sin-facultades-tribunal-ambiental-acogio-reclamacion-contra-resolucion-de-la-sma-que-archivo-denuncia-contra-proyecto-santiago-downtown/
# [23/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/tribunal-ambiental-escuchara-alegatos-en-reclamacion-de-trabajadores-del-mar-de-ventanas-y-horcon-contra-la-sma-por-derrame-de-petroleo-en-quintero/
# [24/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/causa-r-79-2015-acumula-r-80-2015-y-r-81-2015/
# [25/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/derrame-en-quintero-corte-de-apelaciones-de-santiago-confirmo-resolucion-en-que-tribunal-ambiental-se-declaro-incompetente-para-analizar-demanda-por-reparacion-de-dano-ambiental/
# [26/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/presidente-asenjo-dicto-clase-magistral-en-la-x-convencion-internacional-sobre-ambiente-y-desarrollo-que-se-realizo-en-la-habana/
# [27/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/alegan-por-la-resolucion-en-que-la-superintendencia-del-medio-ambiente-archivo-sus-denuncias-contra-proyecto-inmobiliario-en-algarrobo/
# [28/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/minera-alega-contra-la-resolucion-en-que-la-superintendencia-rechazo-el-programa-de-cumplimiento-ambiental-de-pascua-lama/
# [29/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/ministro-sebastian-valdes-participo-en-charla-acerca-del-rol-del-magistrado-cientifico-en-los-tribunales-ambientales/
# [30/285] OK rows=1 pdfs_page=3 | https://tribunalambiental.cl/acceda-informes-ministras-visitadoras-de-la-corte-suprema/
# [31/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/derrame-en-quintero-tribunal-ambiental-de-santiago-se-declaro-incompetente-para-conocer-reclamacion-de-enap-contra-el-fiscal-maritimo-de-valparaiso/
# [32/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-escucho-alegatos-en-causa-asociada-a-proyecto-sistema-de-disposicion-de-relaves-a-largo-plazo-proyecto-embalse-ovejeria-de-codelco-andina/
# [33/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/corte-suprema-confirmo-sentencia-del-tribunal-ambiental-que-rechazo-reclamacion-contra-aprobacion-de-proyecto-minero-paguanta/
# [34/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/alegatos-en-causa-r-96-2016/
# [35/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-autorizo-detencion-de-funcionamiento-de-obras-de-proyecto-inmobiliario-desarrollado-en-precordillera-de-penalolen/
# [36/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-escuchara-alegatos-en-reclamacion-asociada-a-resolucion-de-la-sma-que-declaro-incumplido-programa-de-cumplimiento-presentado-por-la-empresa/
# [37/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/alta-concurrencia-marco-desarrollo-del-ii-foro-internacional-de-justicia-ambiental-organizado-por-el-tribunal/
# [38/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-realizo-audiencia-en-reclamacion-de-cosayach-contra-la-sma-por-rechazar-recurso-de-reposicion-interpuesto-en-contra-de-una-resolucion-sancionatoria/
# [39/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/acogio-reclamacion-tribunal-ambiental-deja-sin-efecto-resolucion-que-aprobo-programa-de-cumplimiento-a-minera-ubicada-en-alhue/
# [40/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/corte-suprema-rechaza-recurso-de-casacion-y-confirma-sentencia-del-tribunal-ambiental/
# [41/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-rechazo-reclamacion-de-los-sindicatos-de-pescadores-de-las-caletas-de-ventanas-y-horcon-contra-la-sma-por-archivar-denuncia-asociada-a-derrame-de-petroleo-en-quintero/
# [42/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-96-2016-plantel-cerdos-quebrada-honda/
# [43/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-72-2015-cerro-casale-sea/
# [44/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-98-2016-ovejeria/
# [45/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-116-2016-sta-marta/
# [46/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-135-2016-comunicado/
# [47/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-28-2016-vichuquen/
# [48/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-cosayach-r-82-2015/
# [49/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-132-2016-codelco-ventanas/
# [50/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/corte-suprema-rechazo-recurso-de-casacion-contra-sentencia-del-tribunal-ambiental-que-confirmo-aprobacion-del-programa-de-cumplimiento-del-relleno-santa-marta/
# [51/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-129-2016/
# [52/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-150-2017-efe/
# [53/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-derrame-petroleo-en-quintero-d-13-2014/
# [54/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-138-2017-mina-invierno/
# [55/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-154-2017-chile-mink/
# [56/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-25-2016-pampa-camarones/
# [57/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-s-64-2018-aridos-cachapoal/
# [58/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-161-2017/
# [59/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-99-2016-metales-mejillones/
# [60/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-148-2017-encon-solar/
# [61/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-155-2017-rosselot-sma-sqm-salar/
# [62/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-23-2016-santa-marta/
# [63/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-124-2016-mmillones-gnl-quintero/
# [64/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-149-2017-inmobiliaria-maitencillo-sur/
# [65/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-36-2017-cde-efe-molymet/
# [66/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-163-2017-frigorifico-linares-sma/
# [67/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-139-2016-pto-viluco/
# [68/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-157-2017-158-rt-sulfuros-codelco/
# [69/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-160-2017-pampa-hermosa-sqm/
# [70/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/detencion_extraccion-aridos-dunas-ritoque-s-66-2018/
# [71/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-153-2017-programa-cumplimiento-santa-marta/
# [72/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-146-2017-puerto-viluco/
# [73/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-maricunga-d-26-27/
# [74/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-confirma-rechazo-torres-habitacionales-estacion-central/
# [75/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-acoge-parcialmente-reclamacion-de-vecino-contra-resolucion-de-calificacion-ambiental-de-proyecto-minero-cerro-colorado/
# [76/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-12-5-2016-revision-rca-proyecto-desarrollo-los-bronces/
# [77/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-198-2018-hidroelectrica-robleria-sma/
# [78/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/ministro-felipe-sabando-desarrollo-diversas-actividades-de-vinculacion-institucional-en-visita-a-la-ciudad-de-talca/
# [79/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/ministro-presidente-s-inauguro-ano-academico-del-magister-en-derecho-ambiental-de-la-universidad-del-desarrollo/
# [80/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-32-2016-acoge-demanda-de-dos-agricultores-de-puchuncavi-contra-minera-montecarmelo/
# [81/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-166-2017-central-de-respaldo-dona-carmen-sea/
# [82/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-170-2018-residuos-en-bosque-panul/
# [83/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-191-2018-reclamacion-contra-sma-discoteque-delphos-norma-ruido/
# [84/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-193-2018-reclamacion-sma-karaoke-bellavista/
# [85/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-164-2017-r-165-2017-cigri-ciclo-tiltil-sea/
# [86/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-179-2018-toro-mazotte-115-sea-acoge/
# [87/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/el-tribunal-ambiental-de-santiago-informa-a-ud-que-el-sistema-electronico-de-gestion-de-causas-se-encuentra-presentando-problemas/
# [88/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencias-casacion-corte-suprema-demanda-santa-marta/
# [89/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-189-2018-embalse-punilla-rechaza/
# [90/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/para-facilitar-el-acceso-a-la-tramitacion-de-causas-le-informamos/
# [91/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/saludo-presidente-corte-suprema-brito/
# [92/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-172-2018-turbus-sma/
# [93/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-197-2018-ruido-la-reina-sma/
# [94/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/tdr_informe-en-derecho-de-analisis-y-legalidad-de-reglamento-interno-de-orden-higiene-y-seguridad/
# [95/285] OK rows=1 pdfs_page=2 | https://tribunalambiental.cl/corte-suprema-confirma-fallo-del-tribunal-ambiental-de-santiago-que-rechazo-construccion-de-edificio-por-impactos-en-medio-humano/
# [96/285] OK rows=1 pdfs_page=2 | https://tribunalambiental.cl/sentencia-casacion-fondo-r-191-2018-ruido/
# [97/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/corte-suprema-ratifico-sentencia-del-tribunal-asociada-a-proyecto-pascua-lama/
# [98/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-190-2018-comunidades-indigenas-sea-central-hidroelectrica-osorno/
# [99/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/plan-de-accion-fomenta-el-acceso-remoto-para-la-entrega-de-escritos-y-otros-tramites-tanto-jurisdiccionales-como-administrativos/
# [100/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-175-2018-reclamacion-central-ciclo-combinado-los-rulos/
# [101/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-209-2019-molymet-seremi-salud/
# [102/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-213-2019-transportes-thomas-sma/
# [103/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-39-2017-altos-yali-municipalidad-santo-domingo-condena/
# [104/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-196-2018-avicolas-sma-talca/
# [105/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-corte-suprema-casacion-central-hidroelectrica-osorno-sea-r-190-2018/
# [106/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r182-2018-agricola-alma-cea-valparaiso-parque-fotovoltaico-panquehe/
# [107/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-181-2018-esval-sea-rechaza/
# [108/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/ministro-presidente-participo-en-inauguracion-del-magister-de-derecho-ambiental-de-la-universidad-del-desarrollo/
# [109/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-199-2018-programa-cumplimiento-codelco-ventanas/
# [110/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunales-ambientales-firman-convenio-para-unificar-el-sistema-de-tramitacion-electronica-de-causas/
# [111/285] OK rows=1 pdfs_page=2 | https://tribunalambiental.cl/fallo-corte-suprema-casacion-r-125-2016-los-bronces-sentencia/
# [112/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-195-2018-autodromo-codegua-multa-sma/
# [113/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-210-2019-ppda-conco-quintero-puchuncavi/
# [114/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-178-2018-piscicultura-calcurrupe-sea/
# [115/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/falta-de-motivacion-tribunal-acogio-reclamacion-de-minera-candelaria-y-ordeno-a-la-superintendencia-del-medio-ambiente-dictar-una-nueva-resolucion-sancionatoria/
# [116/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-212-2019-proyecto-loteo-construccion-penalolen-vecinos-cea-metropolitana/
# [117/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-200-2018-santuario-naturaleza-cartografia-ministerio-medio-ambiente/
# [118/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/publicidad-escritos-tribunal-ambiental/
# [119/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-222-2019-quinta-alimentos-sma-multa-ruido/
# [120/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-192-2018-inmobiliaria-macul-sma/
# [121/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-202-2019-punta-puertecillo-vecinos-sma/
# [122/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-203-2019-comite-ministros-rca-ovejeria-codelco/
# [123/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/agricola-ganadera-claudio-gonzalez-cornejo-eirl-superintendencia-del-medio-ambiente-res-ex-n1-rol-d-170-2020-y-res-ex-n2498-ambas-de-fecha-18-de-febrero-de-2020-admite-a-tramite/
# [124/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-ambiental-de-santiago-condeno-a-la-empresa-minera-jorge-gonzalez-ite-e-i-r-l-y-otros-a-reparar-el-dano-ambiental-causado-en-la-ensenada-el-asiento-en-la-comuna-de-san-felipe/
# [125/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/cuenta-publica-2020-ingreso-de-causas-y-dictacion-de-sentencias-en-el-segundo-tribunal-ambiental-aumento-pese-a-la-pandemia/
# [126/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/segundo-tribunal-ambiental-busca-analista-en-control-de-gestion/
# [127/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/por-falta-de-fundamentacion-tribunal-anulo-resolucion-de-la-sma-que-sanciono-a-productora-de-aceite-de-oliva-con-multa-de-1-916-uta/
# [128/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/aguas-de-antofagasta-s-a-direccion-general-del-territorio-maritimo-y-mercante-res-ex-n-12050-9-vrs-del-22-de-enero-de-2021-admite-a-tramite/
# [129/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/bueno-torres-nora-del-rosari-director-ejecutivo-del-servicio-de-evaluacion-ambiental-rol-r-251-2020/
# [130/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/audiencia-en-reclamacion-rol-r-224-2019-lopez-aranguiz-david-marcial/
# [131/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/corte-suprema-confirmo-sentencia-del-segundo-tribunal-ambiental-que-ordeno-a-la-sma-dictar-nueva-resolucion-sancionatoria-contra-planteles-avicolas-ubicados-en-talca/
# [132/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-237-2020-cuota-pesca-meluza-oceana-ministerio-economia/
# [133/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-acoge-parcialmente-reclamacion-interpuesta-contra-resolucion-asociada-a-invalidacion-de-plan-de-manejo-aprobado-por-conaf/
# [134/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/segundo-tribunal-escucha-alegatos-por-reclamacion-interpuesta-en-contra-de-resolucion-de-coeva-rm-que-rechazo-invalidacion-de-la-rca-del-proyecto-terrazas-del-valle/
# [135/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/segundo-tribunal-ambiental-de-santiago-habilita-nuevo-correo-electronico-para-la-gestion-de-causas/
# [136/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-r253-2020-constructora-sigr-sma/
# [137/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-239-2020-inmobiliaria-laderas-ladomar-sma/
# [138/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-221-2019-urcelay-sma/
# [139/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-251-255-2020-sea-coexca-plantel-cerdos-san-agustin-arbolito-maule/
# [140/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-acogio-reclamacion-enap-por-resolucion-de-la-sma-que-reformulo-cargos-en-su-contra-relacionado-a-episodio-de-intoxicacion-masiva-en-quintero-el-ano-2018/
# [141/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/corte-suprema-rechaza-casacion-fallo-piscicultura-rio-calcurrupe/
# [142/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-236-2020-proyecto-inmobiliario-conjunto-armonico-portezuelo-vitacura/
# [143/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-243-2020-272-2021-puerto-baron-sma/
# [144/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-183-184-185-2018-alto-maipo-sma-programa-cumplimiento/
# [145/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/concurso-publico-control-gestion-personas-2021/
# [146/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-252-2020-terrazas-del-valle-evaluacion/
# [147/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-231-2020-nunoa-egana-comunidad-sustentabe-sea/
# [148/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/sentencia-corte-suprema-casacion-enap-refineria-sma-contaminacion-quintero/
# [149/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-bersa-kennedy-sma-ruido-r-278-2021a-comuna-de-las-condes/
# [150/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-269-2020-townhouse-la-reina-sma-ruido/
# [151/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-aguas-antofagasta-directemar-r-230-2020-multas/
# [152/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/hasta-que-dicte-sentencia-segundo-tribunal-ambiental-ordeno-la-suspension-de-la-rca-del-proyecto-de-sondajes-de-minera-vizcachitas-en-putaendo/
# [153/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-incorporo-a-administradora-publica-veronica-jaduee-como-encargada-de-control-de-gestion/
# [154/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-tcval-rca-sea-puerto-valparaiso/
# [155/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/audiencia-r-310-311-2021-desarrollo-urbano-maratue-puchuncavi-comite-ministros/
# [156/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-232-276-sea-linea-eletrans-ii-ohiggins-metropolitana/
# [157/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-walmart-el-penon-r-215-228-229-260/
# [158/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-273-2021-sma-ganadera-gonzalez/
# [159/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-263-2020-carmen-oriente-huechuraba-sea/
# [160/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-285-2021-red-monitoreo-concon-quintero-puchuncavi-perdida-objeto/
# [161/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-293-2021-allibera-embalse-bullileo-sea/
# [162/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-261-2020-puerto-cruz-grande-sma/
# [163/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-326-2022-municipalidad-llay-llay-sma-ruido/
# [164/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/por-falta-de-fundamentacion-tribunal-anulo-resolucion-de-la-sma-que-archivo-denuncia-contra-anglo-american-sur-por-elusion-al-sistema-de-evaluacion-de-impacto-ambiental/
# [165/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-318-2021-restaurante-caleuche-sma/
# [166/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-310-311-2021-comite-ministros-proyecto-maratue/
# [167/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-296-2021-edificio-urmeneta-limache/
# [168/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-humedal-urbano-quilicura-mma-r-297-298-299-2021/
# [169/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-sea-putaendo-vizcachitas-r-304-2021-325-2022/
# [170/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-307-2021-humedal-urbano-quilpue/
# [171/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-295-2021-sea-rca-planta-residuos-celulosa-arauco-constitucion/
# [172/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-humedal-urbano-los-juanes-mma/
# [173/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-315-2021-humedal-urbano-estero-el-litre-ferronor-mma/
# [174/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-341-2022-humedal-urbano-godoy-pejerreyes-municipalidad-villa-alemana-mma/
# [175/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-266-2020-fundicion-alcones-sma/
# [176/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-265-2020-ptas-machali-rancagua-graneros-sea-rca/
# [177/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-305-306-2021-humedal-urbano-piedras-blancas-limache-mma/
# [178/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-319-2022-humedal-urbano-tranque-la-poza-lo-barnechea/
# [179/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-cimeplas-fabrica-tuberia-plasticos-paine-sag/
# [180/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-277-2021-yarur-corporacion-sma-dunas-concon-reconsa/
# [181/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-289-290-2021-sea-acueducto-quilapilun-rca/
# [182/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-301-309-2021-oleoducto-maipu-aeropuerto/
# [183/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentenciar-316-317-2021-humedal-urbano-estuario-los-molles/
# [184/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-340-2022-sma-lyon-view-ruido/
# [185/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-313-2021-municipalidad-santiago-sea-metro-linea-7/
# [186/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-322-2022-vecinos-melipilla-sma-linea-eletrans/
# [187/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-280-2021-corporacion-vina-del-mar-comite-ministros-punta-piqueros/
# [188/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r282-303-2021-sea-rca-lincan-alimentos-maule/
# [189/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-384-2022-agricola-ribagorza-sma-programa-cumplimiento/
# [190/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-evaluacion-sea-proyecto-hijuelas-quilin-penalolen-r-334-336-2022/
# [191/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-354-2022-consorcio-punta-puyai-mma-humedal/
# [192/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-279-2021-automotoras-neumaticos-ley-rep/
# [193/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-362-2022-sportlife-maipu-sma/
# [194/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-292-2021-sma-acueducto-anglo-american/
# [195/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-281-2021-miguel-torres-sma-archivo-denuncia/
# [196/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-355-2022-humedal-urbano-tunquen/
# [197/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-363-2022-frigorifico-antillal-multa-ruido/
# [198/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-388-2023-edificio-don-alberto-sma-ruido/
# [199/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-349-2022-alcantarillado-cumpeo-muta/
# [200/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-373-2022-loteo-54-casas-barnechea-sma/
# [201/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-376-2022-proyekta-sma-ruido-construccion/
# [202/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-323-2022-sea-meseta-los-andes-fotovoltaico/
# [203/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-395-2023-humedal-urbano-rio-maipo-isla-maipo/
# [204/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-378-2022-edificio-britania-sma-ruido/
# [205/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-353-2022-fotovoltaico-talagante-sma-programa-cumplimiento/
# [206/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-350-2022-constructora-proyekta-sma-ruido/
# [207/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/en-breve-audiencia-en-reclamacion-de-municipalidad-de-maipu-contra-la-aprobacion-ambiental-de-proyecto-edificio-pajaritos/
# [208/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-360-2022-embalse-las-posesiones/
# [209/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-370-2022-flesan-sma-ruido/
# [210/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-348-2022-bosque-panul-arenas-sma2/
# [211/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-352-2022-planta-rembre-quilicura/
# [212/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-343-2022-central-biomasa-la-gloria/
# [213/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r27-270-2020-cerrillos-data-center/
# [214/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-392-2023-eletrans-construccion-helicopteros/
# [215/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-331-2022-linea-6-metro-sma
# [216/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-264-2020-pichidegua-sea-camino-de-la-fruta
# [217/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-78-2022-plantel-avicola-tiltil
# [218/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-385-2023-hidroelectrica-robleria-sma
# [219/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-403-2023-multa-por-ruido-sma-edificio-san-diego
# [220/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-409-2023-ruido-programa-cumplimiento-sma
# [221/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-404-2023-municipalidad-maipu-sea-edificio-pajaritos
# [222/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-396-2023-imelsa-sea-central-dona-carmen
# [223/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-374-2023-prorroga-deposito-pasta-cabildo-sea
# [224/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-383-2022-constructora-sma-edificio-manuel-montt-ruido
# [225/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-400-2023-global-center-sma-ruido
# [226/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-399-2023-caducidad-rca-sea-punta-pite-papudo
# [227/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-399-2023-aridos-cachapoal-sma-multa
# [228/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/conversatorio-aportes-del-tribunal-en-la-resolucion-de-conflictos-ambientales-acontecidos-en-la-region-de-valparaiso/
# [229/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-407-2023-rca-condominio-manantiales-llano
# [230/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-418-2023-aridos-rio-maipo-sma
# [231/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-397-2023-molymet-seremi-salud-rm-retiro-de-asbesto-en-terrenos-de-efe-en-san-bernardo/
# [232/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-432-2023-sma-archivo-denuncia-proyecto-mirador-piedra-trueno
# [233/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/conversatorio-aportes-del-segundo-tribunal-en-la-resolucion-de-conflictos-ambientales-acontecidos-en-la-region-de-valparaiso/
# [234/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-424-2023-ruido-bezanilla-sma
# [235/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-371-solucion-sanitaria-isla-maipo-sea
# [236/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-377-2022-vecinos-sea-proyecto-fotovoltaico-chicureo-solar
# [237/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-405-2023-ruido-entre-sauces-sma
# [238/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-413-2023-ruido-constructora-paz-sma-bartoloii
# [239/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-443-2023-restobar-algarrobo-sma
# [240/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-408-2023-algarrobo-sea-edificio-barlovento
# [241/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-68-2022-vecinos-el-melon-municipalidad-nogales-olores
# [242/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-412-2023-aridos-minera-rosario-puente-alto-sea
# [243/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-417-2023-ex-vertedero-la-feria-municipalidad-pedro-aguirre-cerda-sma
# [244/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-414-2023-vertedero-totoral-quisco-sma
# [245/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-435-2023-fotovoltaico-la-greda
# [246/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-454-2024-ley-sbap-santuario-gota-de-leche-el-tabo
# [247/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-425-2023-ruido-edificio-bucarest-sma
# [248/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-428-2023-edificio-duo-seia
# [249/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-451-ruido-almahue-sma
# [250/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-74-2022-humedal-bucalemu-municipalidad-paredones-mop
# [251/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-d-71-2022-inversiones-lampa-condena-por-dano
# [252/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-450-2024-multa-ruido-comercial-valencia-sma
# [253/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-426-2023-sma-vecinos-aridos-baltierra-puente-alto-pdc
# [254/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-346-2022-efe-sma-fraccionamiento-proyecto-rancagua-express-tren
# [255/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/segundo-tribunal-ambiental-realizara-su-cuenta-publica-2024-y-conversatorio-respecto-de-la-resolucion-alternativa-de-controversias/
# [256/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-enap-sma-sancion-incumplimiento-ppda-concon-quintero-puchuncavi
# [257/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-466-2024-multa-ruido-bersa-kennedy-sma
# [258/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencias-r-433-y-r-434-2023-odfjell-aprobacion-proyectos-fotovoltaicos-sea
# [259/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-456-2024-municipalidad-olmue-sea-plantel-avicola
# [260/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/segundo-tribunal-ambiental-presento-a-sus-pares-de-antofagasta-la-estrategia-desarrollada-en-materia-de-clima-organizacional/
# [261/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-458-2024-exportadora-los-fiordos-sea-caducidad-rca-favorable
# [262/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-464-2024-santuario-naturaleza-rio-cochiguaz-coquimbo
# [263/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-347-439-sea-rca-mall-vivo-santiago
# [264/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-459-2024-humedal-urbano-entre-cerros-vina-del-mar
# [265/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-463-2024-proyecto-inmobiliario-en-san-miguel
# [266/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-proyecto-blanco-7-reclamciones-rca
# [267/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-saneamiento-las-salinas-5-reclamaciones
# [268/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-506-2025-interes-nacional-ruta-t-720-tramo-pn-alerce-costero
# [269/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-483-2024-declaracion-sn-rio-sasso-coquimbo-mma
# [270/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-norma-de-emision-de-radiacion-electromagnetica-asociada-a-equipos-y-redes-de-transmision-de-servicios-de-telecomunicaciones/
# [271/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-482-2024-autorizacion-excavaciones-archipielago-juan-fernandez
# [272/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-470-2024-aceite-oliva-olivares-de-quepu-sma-sancion
# [273/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-465-2024-coexca-planel-cerdos-arbolito-sma
# [274/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/remate-por-cumplimiento-sentencia-ambiental-altos-del-yali
# [275/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencia-r-481-2024-municipalidad-pudahuel-sea-edificio-claudio-arrau
# [276/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/tribunal-consolida-modelo-de-gestion-interna-para-el-analisis-de-causas-de-alto-flujo-dicto-sentencias-en-7-reclamaciones-contra-sanciones-por-ruido/
# [277/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/presentacion-de-escritos/
# [278/285] OK rows=1 pdfs_page=15 | https://tribunalambiental.cl/informes-de-ejecucion-presupuestaria/
# [279/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/sentencias-e-informes/
# [280/285] OK rows=15 pdfs_page=14 | https://tribunalambiental.cl/sentencias-e-informes/informes-de-derecho/
# [281/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/sentencias-e-informes/informes-tecnicos/
# [282/285] OK rows=289 pdfs_page=457 | https://tribunalambiental.cl/sentencias-e-informes/sentencias/
# [283/285] OK rows=1 pdfs_page=0 | https://tribunalambiental.cl/quienes-pueden-iniciar-una-causa/
# [284/285] OK rows=1 pdfs_page=11 | https://tribunalambiental.cl/informes-de-los-ministrosas-visitadores-de-la-corte-suprema/
# [285/285] OK rows=1 pdfs_page=1 | https://tribunalambiental.cl/informes-tecnicos/
#
# == Listo ==
# Registros (dedup): 587
# CSV: /content/tribunalambiental_consolidado.csv

# %%
import pandas as pd

in_path = "/content/tribunalambiental_consolidado.csv"
out_path = "/content/tribunalambiental_consolidado.xlsx"

# Lee CSV y exporta a Excel
df = pd.read_csv(in_path, dtype=str, encoding="utf-8", keep_default_na=False)
df.to_excel(out_path, index=False)

print("Listo:", out_path)
# Out:
# Listo: /content/tribunalambiental_consolidado.xlsx

# %%
import os
import re
import time
import csv
import hashlib
from urllib.parse import urlparse, unquote

import pandas as pd
import requests

# -------------------------
# CONFIG
# -------------------------
INPUT_CSV = "/content/tribunalambiental_scraping.csv"
OUT_DIR = "/content/tribunal_pdfs"
MANIFEST_CSV = "/content/tribunal_pdfs_manifest.csv"

SLEEP_SECONDS = 0.7
TIMEOUT = 60
MAX_RETRIES = 3
CHUNK_SIZE = 1024 * 256  # 256 KB

HEADERS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122 Safari/537.36",
    "Accept": "application/pdf,*/*;q=0.8",
    "Accept-Language": "es-CL,es;q=0.9,en;q=0.8",
}

# -------------------------
# LECTURA CSV
# -------------------------
def robust_read_csv(path: str) -> pd.DataFrame:
    # autodetect separador y tolera líneas rotas
    return pd.read_csv(
        path,
        dtype=str,
        keep_default_na=False,
        sep=None,
        engine="python",
        on_bad_lines="skip"
    )

def split_field(val: str):
    if not isinstance(val, str) or not val.strip():
        return []
    return [p.strip() for p in val.split("|") if p.strip()]

# -------------------------
# NOMBRES DE ARCHIVO
# -------------------------
def sanitize_filename(name: str) -> str:
    name = unquote(name)
    name = name.strip().replace("\n", " ").replace("\r", " ")
    name = re.sub(r"[^\w\-.() \[\]]+", "_", name, flags=re.UNICODE)
    name = re.sub(r"\s+", " ", name).strip()
    if len(name) > 160:
        base, ext = os.path.splitext(name)
        name = base[:140] + ext
    return name

def filename_from_content_disposition(cd: str) -> str | None:
    # intenta extraer filename=... o filename*=utf-8''...
    if not cd:
        return None
    cd_low = cd.lower()

    # filename*=UTF-8''...
    m = re.search(r"filename\*\s*=\s*([^;]+)", cd, flags=re.I)
    if m:
        v = m.group(1).strip().strip('"').strip()
        # formato típico: UTF-8''archivo.pdf
        v = re.sub(r"^utf-8''", "", v, flags=re.I)
        v = v.strip()
        if v:
            return sanitize_filename(v)

    # filename="..."
    m = re.search(r'filename\s*=\s*"([^"]+)"', cd, flags=re.I)
    if m:
        return sanitize_filename(m.group(1))

    # filename=...
    m = re.search(r"filename\s*=\s*([^;]+)", cd, flags=re.I)
    if m:
        return sanitize_filename(m.group(1).strip().strip('"'))

    return None

def unique_path(path: str) -> str:
    if not os.path.exists(path):
        return path
    root, ext = os.path.splitext(path)
    i = 2
    while True:
        cand = f"{root}_{i}{ext}"
        if not os.path.exists(cand):
            return cand
        i += 1

def fallback_filename(url: str) -> str:
    # nombre estable por hash (evita problemas de URL sin basename)
    h = hashlib.sha1(url.encode("utf-8", errors="ignore")).hexdigest()[:16]
    return f"document_{h}.pdf"

# -------------------------
# DESCARGA + VALIDACIÓN PDF
# -------------------------
def download_and_verify_pdf(session: requests.Session, url: str, out_dir: str) -> dict:
    rec = {
        "url": url,
        "final_url": "",
        "status": "",
        "file_path": "",
        "bytes": 0,
        "content_type": "",
        "error": "",
    }

    for attempt in range(1, MAX_RETRIES + 1):
        try:
            with session.get(url, headers=HEADERS, timeout=TIMEOUT, stream=True, allow_redirects=True) as r:
                rec["status"] = str(r.status_code)
                rec["final_url"] = r.url
                rec["content_type"] = (r.headers.get("content-type") or "").lower()

                if r.status_code != 200:
                    raise RuntimeError(f"HTTP {r.status_code}")

                # define nombre desde headers si se puede
                cd = r.headers.get("content-disposition") or ""
                fname = filename_from_content_disposition(cd)
                if not fname:
                    # si la URL trae basename útil, úsalo; si no, hash
                    base = os.path.basename(urlparse(r.url).path) or ""
                    base = sanitize_filename(base) if base else ""
                    if base.lower().endswith(".pdf"):
                        fname = base
                    else:
                        fname = fallback_filename(r.url)

                if not fname.lower().endswith(".pdf"):
                    fname += ".pdf"

                fpath = unique_path(os.path.join(out_dir, fname))
                tmp = fpath + ".part"

                total = 0
                with open(tmp, "wb") as f:
                    for chunk in r.iter_content(chunk_size=CHUNK_SIZE):
                        if chunk:
                            f.write(chunk)
                            total += len(chunk)

                # Validación fuerte: firma PDF
                with open(tmp, "rb") as f:
                    head = f.read(5)

                if head != b"%PDF-":
                    # no es PDF: NO lo guardamos
                    os.remove(tmp)
                    raise RuntimeError(f"No es PDF real (firma={head!r}, ct={rec['content_type']})")

                os.rename(tmp, fpath)
                rec["file_path"] = fpath
                rec["bytes"] = total
                return rec

        except Exception as e:
            rec["error"] = f"attempt {attempt}/{MAX_RETRIES}: {e}"
            time.sleep(1.5 * attempt)

    return rec

# -------------------------
# RUN
# -------------------------
if not os.path.exists(INPUT_CSV):
    raise FileNotFoundError(
        f"No encuentro {INPUT_CSV}. Revisa el panel Files o corre: !ls -lh /content"
    )

os.makedirs(OUT_DIR, exist_ok=True)

print("Leyendo CSV...")
df = robust_read_csv(INPUT_CSV)
print("OK. shape:", df.shape)

# Extraer URLs (sin filtrar por extensión; se valida al descargar)
urls = []
for col in ["pdf_links_row", "pdf_links_page"]:
    if col in df.columns:
        for v in df[col].tolist():
            urls.extend(split_field(v))
    else:
        print(f"[WARN] No existe la columna {col}")

urls = [u.strip() for u in urls if isinstance(u, str) and u.strip()]

# dedup conservando orden
seen = set()
urls_uniq = []
for u in urls:
    if u not in seen:
        urls_uniq.append(u)
        seen.add(u)

print("URLs totales (dedup):", len(urls_uniq))
print("Descargando a:", OUT_DIR)

manifest_exists = os.path.exists(MANIFEST_CSV)
with open(MANIFEST_CSV, "a", newline="", encoding="utf-8") as mf:
    writer = csv.DictWriter(
        mf,
        fieldnames=["url", "final_url", "status", "file_path", "bytes", "content_type", "error"],
    )
    if not manifest_exists:
        writer.writeheader()

    ok = 0
    fail = 0
    with requests.Session() as session:
        for i, url in enumerate(urls_uniq, start=1):
            rec = download_and_verify_pdf(session, url, OUT_DIR)
            writer.writerow(rec)
            mf.flush()

            if rec["file_path"]:
                ok += 1
                print(f"[{i}/{len(urls_uniq)}] OK   {rec['bytes']} bytes -> {os.path.basename(rec['file_path'])}")
            else:
                fail += 1
                print(f"[{i}/{len(urls_uniq)}] FAIL {url} | {rec['error']}")

            time.sleep(SLEEP_SECONDS)

print("\n== Resumen ==")
print("OK:", ok)
print("FAIL:", fail)
print("Manifest:", MANIFEST_CSV)
print("PDFs en:", OUT_DIR)
# Out:
# Leyendo CSV...
# OK. shape: (587, 12)
# [WARN] No existe la columna pdf_links_page
# URLs totales (dedup): 295
# Descargando a: /content/tribunal_pdfs
# [1/295] OK   373676 bytes -> R-06-2013-Informe-en-derecho-de-don-Jorge-Bermudez-Soto_2.pdf
# [2/295] OK   7813284 bytes -> R-40-Informe-en-Derecho-Andres-Bordali_2.pdf
# [3/295] OK   466814 bytes -> R-06-2013-Informe-en-derecho-de-don-Luis-Cordero-Vega_2.pdf
# [4/295] OK   1412847 bytes -> R-45-2014-06-01-2015-Doc.-Informe-en-Derecho-Luis-Cordero-Vega._2.pdf
# [5/295] OK   1481462 bytes -> R-06-2013-Informe-en-derecho-de-don-Gabriel-Del-Favero-Valdes_2.pdf
# [6/295] OK   141634 bytes -> R-06-2013_Informe_en_Derecho_Sr-Patricio-Leyton-Florez_2.pdf
# [7/295] OK   595466 bytes -> R-40-Opinion-Legal-Cristian-Maturana_2.pdf
# [8/295] OK   6692149 bytes -> R-40-Informe-en-Derecho-Cristian-Maturana-y-Jaime-Jara_2.pdf
# [9/295] OK   268712 bytes -> Informe-en-derecho-concurso-infraccional-imperfecto-Jean-Pierre-Matus_2.pdf
# [10/295] OK   5820709 bytes -> R-40-2014-Informe-en-Derecho-Claudio-Moraga_2.pdf
# [11/295] OK   164629 bytes -> Informe_en_derecho-_Terceros_Coadyuvantes_en_Casacion-_A-Romero-Seguel_2.pdf
# [12/295] OK   422641 bytes -> R-07-2013-Informe-en-derecho-de-don-Alejandro-Romero-Seguel1_2.pdf
# [13/295] OK   498633 bytes -> R-16-2013-Informe-Alejandro-Romero-Sequel_2.pdf
# [14/295] OK   183383 bytes -> R-06-2013-Informe-en-derecho-de-don-Rodrigo-Silva-Montes1_2.pdf
# [15/295] OK   3117193 bytes -> 2025.12.05_Sentencia_R-481-2024__2.pdf
# [16/295] OK   2376656 bytes -> 2025.10.30_Sentencia_R-465-2024_2.pdf
# [17/295] OK   5027820 bytes -> 2025.10.09_Sentencia_R-327-2022_R328_R335_R337_R338_R447_2.pdf
# [18/295] OK   1083712 bytes -> 2025.10.02_Sentencia_R-482-2024_2.pdf
# [19/295] OK   1144484 bytes -> 2025.09.30_Sentencia_R-522-2025_2.pdf
# [20/295] OK   672824 bytes -> 2025.09.17_Sentencia_R-470-2024_2.pdf
# [21/295] OK   1458127 bytes -> 2025.09.15_Sentencia_R-504-2025_2.pdf
# [22/295] OK   2126201 bytes -> 2025.08.29_Sentencia_R-483-2024_2.pdf
# [23/295] OK   1249306 bytes -> 2025.08.29_Sentencia_R-453-2024_2.pdf
# [24/295] OK   789358 bytes -> 2025.08.25_Sentencia_R-506-2025_2.pdf
# [25/295] OK   16696657 bytes -> 2025.08.19_Sentencia_R-375-2022_y_acumuladas-1_2.pdf
# [26/295] OK   12478077 bytes -> Sentencia_R-333-2022_2.pdf
# [27/295] OK   1813581 bytes -> 2025.07.07_Sentencia_R-463-2024_2.pdf
# [28/295] OK   3335289 bytes -> 2025.07.03_Sentencia_R-459-2024_2.pdf
# [29/295] OK   2539625 bytes -> 2025.06.03_Sentencia_R-347-2022_acumulada_R-439-2023_2.pdf
# [30/295] OK   688031 bytes -> 2025.05.29_Sentencia_R-479-2024_2.pdf
# [31/295] OK   1920015 bytes -> 2025.05.16_Sentencia_R-464-2024_2.pdf
# [32/295] OK   1608534 bytes -> 2025.04.17_Sentencia_R-458-2024_2.pdf
# [33/295] OK   1388561 bytes -> 2025.03.27_Sentencia_R-456-2024_2.pdf
# [34/295] OK   1541807 bytes -> 2025.03.19_Sentencia_R-434-2023_2.pdf
# [35/295] OK   2286939 bytes -> 2025.03.19_Sentencia_R-433-2023_2.pdf
# [36/295] OK   732507 bytes -> 2025.03.13_Sentencia_R-466-2024_2.pdf
# [37/295] OK   1139502 bytes -> 2025.02.19_Sentencia_R427-2023_R_431-2023_2.pdf
# [38/295] OK   1959513 bytes -> 2025.02.11_Sentencia_R-346-2022_2.pdf
# [39/295] OK   1864393 bytes -> Sentencia_R_426-2023_2.pdf
# [40/295] OK   814878 bytes -> 2024.12.23_Sentencia_R-450-2024_2.pdf
# [41/295] OK   900539 bytes -> 2024.11.15_Sentencia_R-451-2024_2.pdf
# [42/295] OK   663643 bytes -> 2024.11.07_Sentencia_R-428-2023_2.pdf
# [43/295] OK   124866 bytes -> R-398-2023-aprueba-concilacion_2.pdf
# [44/295] OK   1384627 bytes -> 2024.11.06_Sentencia_R-425-2023_2.pdf
# [45/295] OK   796862 bytes -> 2024.11.04_Sentencia_R-454-2024_2.pdf
# [46/295] OK   3447688 bytes -> 2024.10.29_Sentencia_R-406-2023_2.pdf
# [47/295] OK   1693729 bytes -> 2024.09.16_Sentencia_R-435-2023_2.pdf
# [48/295] OK   1834990 bytes -> 2024.08.27_Sentencia_R-414-2023_2.pdf
# [49/295] OK   969882 bytes -> 2024.08.22_Sentencia_R-417-2023_2.pdf
# [50/295] OK   778912 bytes -> 2024.08.14_Sentencia_R-412-2023_2.pdf
# [51/295] OK   1203824 bytes -> 2024.07.17_Sentencia_R-408-2023_2.pdf
# [52/295] OK   593957 bytes -> 2024.07.17_Sentencia_R-443-2023_2.pdf
# [53/295] OK   824470 bytes -> 2024.07.17_Sentencia_R-440-2023_2.pdf
# [54/295] OK   1018161 bytes -> 2024.07.03_Sentencia_R-413-2023_2.pdf
# [55/295] OK   1080506 bytes -> 2024.07.03_Sentencia_R-405-2023_2.pdf
# [56/295] OK   2009047 bytes -> 2024.06.28_Sentencia_R-377-2023_2.pdf
# [57/295] FAIL https://tribunalambiental.cl/wp-content/uploads/2024/06/Sentencia-R-371-2022.pdf | attempt 3/3: HTTP 404
# [58/295] OK   2654198 bytes -> Sentencia_R-371-2022_2.pdf
# [59/295] OK   1408993 bytes -> 2024.06.07_Sentencia_R-424-2023_2.pdf
# [60/295] OK   1438297 bytes -> 2024.05.31_Sentencia_R-432-2023_2.pdf
# [61/295] OK   889386 bytes -> 2024.05.30_Sentencia_R-397-2023_2.pdf
# [62/295] OK   772228 bytes -> 2024.05.27_Sentencia_R-418-2023_2.pdf
# [63/295] OK   1382583 bytes -> 2024.05.27_Sentencia_R-407-2023_2.pdf
# [64/295] OK   1123815 bytes -> 2024.04.30_Sentencia_R-379-2022_2.pdf
# [65/295] OK   888425 bytes -> 2024.04.26_Sentencia_R-400-2023_2.pdf
# [66/295] OK   1212744 bytes -> 2024.04.26_Sentencia_R-399-2023_2.pdf
# [67/295] OK   1018589 bytes -> 2024.04.24_Sentencia_R-383-2022_2.pdf
# [68/295] OK   997348 bytes -> 2024.04.24_Sentencia_R-374-2022_2.pdf
# [69/295] OK   615597 bytes -> 2024.04.22_Sentencia_R-396-2023_2.pdf
# [70/295] OK   5405224 bytes -> 2024.04.22_Sentencia_R-404-2023_2.pdf
# [71/295] OK   950812 bytes -> 2024.04.15_Sentencia_R-409-2023_2.pdf
# [72/295] OK   1351333 bytes -> 2024.04.11_Sentencia_R-403-2023-1_2.pdf
# [73/295] OK   3580430 bytes -> 2024.04.08_Sentencia_R-385-2023_2.pdf
# [74/295] OK   1121884 bytes -> 2024.03.19_Sentencia_R-264-2020_2.pdf
# [75/295] OK   1921749 bytes -> 2024.03.11_Sentencia_R-331-2022_2.pdf
# [76/295] OK   1631145 bytes -> Sentencia_R-392-2023_2.pdf
# [77/295] OK   1827182 bytes -> 2024.02.26_Sentencia_R-271_270-2020_2.pdf
# [78/295] OK   1457886 bytes -> Sentencia_R_352-2022_2.pdf
# [79/295] OK   1061622 bytes -> 2024.02.09_Sentencia_R-343-2022_2.pdf
# [80/295] OK   1450748 bytes -> 2024.01.26_Sentencia_Rol-348-2022_2.pdf
# [81/295] OK   916060 bytes -> 2023.12.20_Sentencia_R-370-2022_2.pdf
# [82/295] OK   2283958 bytes -> 2023.12.07_Sentencia_R-360-2022_2.pdf
# [83/295] OK   106816 bytes -> R-308-2021_2.pdf
# [84/295] OK   628849 bytes -> 2023.11.20_Sentencia_R-350-2022_2.pdf
# [85/295] OK   896082 bytes -> 2023.11.02_Sentencia_R-353-2022_2.pdf
# [86/295] OK   687660 bytes -> 2023.10.25_Sentencia_R-378-2022_2.pdf
# [87/295] OK   492759 bytes -> 2023.10.19_Sentencia_R-395-2023_2.pdf
# [88/295] OK   1231011 bytes -> 2023.10.12_Sentencia_R-323-2022_2.pdf
# [89/295] OK   1057334 bytes -> 2023.10.11_Sentencia_R-376-2022_2.pdf
# [90/295] OK   1270696 bytes -> 2023.09.13_Sentencia_R-373-2022_2.pdf
# [91/295] OK   4115671 bytes -> 2023.09.06_Sentencia_R-349-2022_2.pdf
# [92/295] OK   1004383 bytes -> 2023.08.23_Sentencia_R-388-2023_2.pdf
# [93/295] OK   820566 bytes -> 2023.08.22_Sentencia_R-363-2023_2.pdf
# [94/295] OK   1349291 bytes -> 2023.08.17_Sentencia_R-355-2022_2.pdf
# [95/295] OK   1211987 bytes -> 2023.08.10_Sentencia_R-292-2021_2.pdf
# [96/295] OK   1610246 bytes -> 2023.08.08_Sentencia_R-281-2021_2.pdf
# [97/295] OK   2053470 bytes -> R-356-2022_26-07-2023_Sentencia_2.pdf
# [98/295] OK   830313 bytes -> R-279-2021_26-07-2023_Sentencia_2.pdf
# [99/295] OK   1453734 bytes -> R-362-2022_19-07-2023_Sentencia_2.pdf
# [100/295] OK   843073 bytes -> R-354-2022_19-07-2023_Sentencia_2.pdf
# [101/295] OK   3518544 bytes -> R-334-2022_18-07-2023_Sentencia_2.pdf
# [102/295] OK   450750 bytes -> 2023.07.10_Sentencia_R-384-2022_2.pdf
# [103/295] OK   3933282 bytes -> 2023.06.30_Sentencia_R-282-2021_acumulada_R-303-2021_2.pdf
# [104/295] OK   983648 bytes -> 2023.05.11_Sentencia_R-342-2022_2.pdf
# [105/295] OK   1096267 bytes -> 2023.04.25_Sentencia_R-280-2021_2.pdf
# [106/295] OK   907577 bytes -> 2023.04.19_Sentencia_R-313-2021_2.pdf
# [107/295] OK   2390263 bytes -> Sentencia_R-322-2022_2.pdf
# [108/295] OK   1089717 bytes -> R-340-2022_16-03-2023_Sentencia_2.pdf
# [109/295] OK   2296054 bytes -> Sentencia_R-324-2022-1_2.pdf
# [110/295] OK   948816 bytes -> 2022.02.24_Sentencia_R-344-2022-1_2.pdf
# [111/295] OK   2478892 bytes -> Sentencia_R_N_240-2020.-1_2.pdf
# [112/295] OK   4897264 bytes -> 2023.01.30_Sentencia_R-301-2021_acumulada_R-309-202133131_2.pdf
# [113/295] OK   1760810 bytes -> 2023.01.30_Sentencia_R_316-2021_acumulada_R_317-2021_2.pdf
# [114/295] OK   3627659 bytes -> 2023.01.30_Sentencia_R-289-290__2.pdf
# [115/295] OK   1033493 bytes -> Sentencia_Rol_N_314-2021_002_2.pdf
# [116/295] OK   2249781 bytes -> R-277-2021_30-12-2022_Sentencia-4_2.pdf
# [117/295] OK   1940494 bytes -> 2022.12.30_Sentencia_R-265-2020-1_2.pdf
# [118/295] OK   755216 bytes -> 2022.12.19_Sentencia_R-319-2022-1_2.pdf
# [119/295] OK   1256230 bytes -> R-266-2020_19-12-2022_Sentencia_foliada_2.pdf
# [120/295] OK   1565947 bytes -> R-305-2021_16-12-2022_Sentencia_foliada-2_2.pdf
# [121/295] OK   1106130 bytes -> 2022.12.02_Sentencia_R-341-2022_2.pdf
# [122/295] OK   530488 bytes -> 2022.11.30_Sentencia_R-283-2021_2.pdf
# [123/295] OK   874091 bytes -> 2022.11.24_Sentencia_R-315-2021_2.pdf
# [124/295] OK   125935 bytes -> R-315-2022-CS_2.pdf
# [125/295] OK   621761 bytes -> 2022.11.21_Sentencia_R-339-2022-2_2.pdf
# [126/295] OK   922300 bytes -> 2022.11.09_Sentencia_R_295-2021_2.pdf
# [127/295] OK   896271 bytes -> 2022.11.02_Sentencia_R-307-2021_2.pdf
# [128/295] OK   792688 bytes -> 2022.10.26_Sentencia_R-304-2021acum.R325-2022_2.pdf
# [129/295] OK   1817733 bytes -> 2022.10.24_Sentencia_R-297-298-299_2.pdf
# [130/295] OK   1315770 bytes -> 2022.10.05_Sentencia_R-310_311-2021_2.pdf
# [131/295] OK   130152 bytes -> R-310-2022_CS_2.pdf
# [132/295] OK   777454 bytes -> R-318-2021_26-09-2022_Sentencia_2.pdf
# [133/295] OK   2352401 bytes -> R-267-2020_12-09-2022_Sentencia_2.pdf
# [134/295] OK   597452 bytes -> 2022.09.06_Sentencia_R-326-2022_2.pdf
# [135/295] OK   1299405 bytes -> 2022.08.24_Sentencia_R-261-2020_2.pdf
# [136/295] OK   550839 bytes -> 2022.07.25_Sentencia_R-293-2021__2.pdf
# [137/295] OK   345837 bytes -> 2022.07.22_Sentencia_R-285-2021_2.pdf
# [138/295] OK   2574804 bytes -> 2022.07.20_Sentencia_R-263-2020_2.pdf
# [139/295] OK   1907176 bytes -> 2022.07.12_Sentencia_R-273-2021_2.pdf
# [140/295] OK   4347493 bytes -> 2022.07.06_Sentencia_R-215-2019_2.pdf
# [141/295] OK   1373619 bytes -> 2022.06.28_Sentencia_R-232_y_276_2.pdf
# [142/295] OK   31106612 bytes -> R-244-2020_25-05-2022_Sentencia_2.pdf
# [143/295] OK   3313070 bytes -> R-230-2020_10-03-2022_Sentencia_2.pdf
# [144/295] OK   3613240 bytes -> R-269-2020_28-02-2022_Sentencia_foliada_2.pdf
# [145/295] OK   5010303 bytes -> R-278-2021_24-02-2022_Sentencia_2.pdf
# [146/295] OK   2368486 bytes -> Sentencia_R_231-2020-25.11.2021_2.pdf
# [147/295] OK   307698 bytes -> 1085-2022-Casacion_2.pdf
# [148/295] OK   153256 bytes -> 1085-2022-Sentencia-de-reemplazo_2.pdf
# [149/295] OK   8137647 bytes -> R-252-2020_19-11-2021_Sentencia_2.pdf
# [150/295] OK   27683720 bytes -> R-183-2018_03-11-2021_Sentencia_2.pdf
# [151/295] OK   144969 bytes -> Sentencia_CS_96002-2021_2TA_R-183-2018_2.pdf
# [152/295] OK   1194028 bytes -> R-243-2020_14-10-2021_Sentencia_2.pdf
# [153/295] OK   1565329 bytes -> R-236-2020_01-10-2021_Sentencia_2.pdf
# [154/295] OK   1591757 bytes -> R-262-2020_12-08-2021_Sentencia_2.pdf
# [155/295] OK   123108 bytes -> Sentencia_CS_82391-2021_2TA_R-262-2020_2.pdf
# [156/295] OK   5049164 bytes -> R-251-2020_09-08-2021_Sentencia_2.pdf
# [157/295] OK   21167593 bytes -> Sentencia_R-221-2019_2.pdf
# [158/295] OK   21422078 bytes -> R-239-2020_14-07-2021_Sentencia_2.pdf
# [159/295] OK   145655 bytes -> Sentencia-CS-Inmobiliaria-Laderas-Ladomar-S.A.-con-SMA_2.pdf
# [160/295] OK   2832234 bytes -> R-253-2020_13-07-2021_Sentencia_2.pdf
# [161/295] OK   16356430 bytes -> R-234-2020_22-06-2021_Sentencia_2.pdf
# [162/295] OK   9632498 bytes -> R-233-2020_18-06-2021_Sentencia_2.pdf
# [163/295] OK   10658289 bytes -> R-224-2019_17-06-2021_Sentencia_2.pdf
# [164/295] OK   14497799 bytes -> R-238-2020_16-06-2021_Sentencia_2.pdf
# [165/295] OK   207270 bytes -> Sentencia_CS_58263-2021_2TA_R-238-2020_2.pdf
# [166/295] OK   17970550 bytes -> Sentencia_R_237-2020-13.05.2021_2.pdf
# [167/295] OK   20349256 bytes -> Sentencia_R_208-2019-14.04.2021_2.pdf
# [168/295] OK   13322127 bytes -> Sentencia_R_226-2020-09.04.2021_2.pdf
# [169/295] OK   151504 bytes -> SCS-rol-34697-2021.-Tapia-Azocar-con-SMA.-Acoge-casacion_2.pdf
# [170/295] OK   140498 bytes -> SCS-rol-34697-2021.-Tapia-Azocar-con-SMA.-Sentencia-de-Reemplazo_2.pdf
# [171/295] OK   22587915 bytes -> Sentencia_R_219-2019-05-04-2021_2.pdf
# [172/295] OK   9393715 bytes -> R-220-2019_30-03-2021_Sentencia_2.pdf
# [173/295] OK   182725 bytes -> R-207-2919_Rol-Corte-Suprema_18.996-2021_2.pdf
# [174/295] OK   177570 bytes -> Rol-N_-22.343-2021-casacion_2.pdf
# [175/295] OK   106249 bytes -> Rol-N_-22.343-2021-reemplazo_2.pdf
# [176/295] OK   193251 bytes -> Sentencia_Corte-Suprema_6960-2021-R-200-2018-STA_2.pdf
# [177/295] OK   231960 bytes -> 5.374-2021-casacion_2.pdf
# [178/295] OK   143351 bytes -> 5.374-2021-reemplazo_2.pdf
# [179/295] OK   292697 bytes -> Candelaria-Casacion_2.pdf
# [180/295] OK   199142 bytes -> Candelaria-Reemplazo_2.pdf
# [181/295] OK   161749 bytes -> SCS.-154847-2020.-Maturana-con-SEA.-R-178-2018_2.pdf
# [182/295] OK   934472 bytes -> Sentencia_R-210-2019_-_14.10.2020_2.pdf
# [183/295] OK   4375973 bytes -> 2024-12-27_Sentencia_D-71-2022_2.pdf
# [184/295] OK   3120732 bytes -> 2024-12-16_Sentencia_D-74-2022_2.pdf
# [185/295] OK   2072128 bytes -> Sentencia_D-68-2022_2.pdf
# [186/295] OK   817872 bytes -> 2024.03.28_Sentencia_D-78-2022_2.pdf
# [187/295] OK   148552 bytes -> Sentencia_Corte-Suprema_Rol-31.124-2021_2TA_D-37-2017_2.pdf
# [188/295] OK   170953 bytes -> Sentencia_Corte-Suprema_79079-2020_2TA-D-39-2017_2.pdf
# [189/295] OK   1311789 bytes -> Sentencia-D-32-2016_2.pdf
# [190/295] OK   3318528 bytes -> D-26-2016-23-11-2018-Sentencia_2.pdf
# [191/295] OK   183876 bytes -> Sentencia_Corte_Suprema_Rol_1583-2019_2TA_D-26-2016_2.pdf
# [192/295] OK   10929781 bytes -> D-27-2016-22-11-2018-Sentencia_2.pdf
# [193/295] OK   184555 bytes -> Sentencia_Corte_Suprema_Rol_27726-2019_2TA_D-27-2016_2.pdf
# [194/295] OK   1070735 bytes -> D-36-2017-28-06-2018-Sentencia_2.pdf
# [195/295] OK   172586 bytes -> Sentencia_CS-60804-2021_2TA_D-36-2017-1_2.pdf
# [196/295] OK   21474274 bytes -> D-23-2016-11-05-2018-Sentencia_2.pdf
# [197/295] OK   243257 bytes -> Sentencia-CS-15247_2018_D-23-2016_2.pdf
# [198/295] OK   2473555 bytes -> D-25-2016-29-03-2018-Sentencia_2.pdf
# [199/295] OK   4645335 bytes -> D-13-2014-13-03-2018-Sentencia_2.pdf
# [200/295] OK   271752 bytes -> CS_13177-2018_2TA_D-13-2014_Sentencia_2.pdf
# [201/295] OK   179323 bytes -> CS_13177-2018_2TA_D-13-2014_Sentencia-reemplazo_2.pdf
# [202/295] OK   4436893 bytes -> D-28-2016-31-07-2017-Sentencia_2.pdf
# [203/295] OK   197301 bytes -> Sentencia-CS-acoge-casación-forma-caso-Inversiones-Las-Agatas-con-malhue-Gross-41417-2017-D-28-2016_2.pdf
# [204/295] OK   172768 bytes -> Reemplazo-caso-Inversiones-Las-Agatas-con-Malhue-Gross-Rol-41417-2017-D28-2016_2.pdf
# [205/295] OK   1958450 bytes -> D-17-2015-07-07-2017-Sentencia_2.pdf
# [206/295] OK   195044 bytes -> Sentencia-casación-Rol-37273-2017-Nogales_2.pdf
# [207/295] OK   142402 bytes -> Sentencia-de-reemplazo-Rol-37273-2017-Nogales_2.pdf
# [208/295] OK   3724053 bytes -> D-24-2016-27-04-2017-Sentencia_2.pdf
# [209/295] OK   139383 bytes -> D-24-2016-Aguas-Andina_2.pdf
# [210/295] OK   2013969 bytes -> D-15-2015-06-01-2017-Sentencia_2.pdf
# [211/295] OK   2890785 bytes -> D-14-2014-24-08-2016-Sentencia_2.pdf
# [212/295] OK   4166692 bytes -> D-03-2013-10-04-2015-Sentencia-foliada_2.pdf
# [213/295] OK   1441577 bytes -> D-02-2013-20-03-2015-Sentencia_2.pdf
# [214/295] OK   789515 bytes -> D-09-2014-26-01-2015-Sentencia_2.pdf
# [215/295] OK   27029 bytes -> Sentencia-Casacion_D-9-2014_Catemu_2.pdf
# [216/295] OK   1940767 bytes -> D-06-2013-29-11-2014-Sentencia-Foliada_2.pdf
# [217/295] OK   135145 bytes -> C-06-2016-13-07-2016-Resolucion_2.pdf
# [218/295] OK   346385 bytes -> C-04-2015-08-09-2015-Sentencia_2.pdf
# [219/295] OK   16697 bytes -> C-3-2014_29-01-2015_Resolucion_2.pdf
# [220/295] OK   91241 bytes -> C-02-2013-29-07-2013-Sentencia_2.pdf
# [221/295] OK   72365 bytes -> C-02-2013-11-11-2013-Sentencia-1_2.pdf
# [222/295] OK   77085 bytes -> C-01-2013-29-07-2013-Sentencia_2.pdf
# [223/295] OK   240881 bytes -> 2025.04.11_Sentencia_S-86-2025_2.pdf
# [224/295] OK   237687 bytes -> 2025.03.25_Sentencia_S-85-2025_2.pdf
# [225/295] OK   245789 bytes -> 2025.02.20_Sentencia_S-84-2025_2.pdf
# [226/295] OK   145376 bytes -> S-83-2024_2.pdf
# [227/295] OK   130187 bytes -> S-82-2024-1_2.pdf
# [228/295] OK   667879 bytes -> 2023.12.15_Sentencia_S-81-2023_2.pdf
# [229/295] OK   150614 bytes -> 2023.11.09_Sentencia_S-80-2023_2.pdf
# [230/295] OK   105315 bytes -> S-79-2023_2.pdf
# [231/295] OK   94257 bytes -> S-78-2023_2.pdf
# [232/295] OK   103688 bytes -> S-77-2023_2.pdf
# [233/295] OK   188006 bytes -> S-68-2019-29-03-2019-Resolución_2.pdf
# [234/295] OK   481574 bytes -> S-67-2019-01-03-2019-Resolución_2.pdf
# [235/295] OK   3307528 bytes -> S-66-2018-31-08-2018-Resolución_2.pdf
# [236/295] OK   544633 bytes -> S-65-2018-27-06-2018-Resolución_2.pdf
# [237/295] OK   2441954 bytes -> S-64-2018-17-04-2018-Resolución_2.pdf
# [238/295] OK   539435 bytes -> S-63-2017-18-04-2017-Resolucion_2.pdf
# [239/295] OK   407929 bytes -> S-62-2017-06-04-2017-Resolucion_2.pdf
# [240/295] OK   720286 bytes -> S-61-2017-07-03-2017-Resolucion_2.pdf
# [241/295] OK   491956 bytes -> S-60-2017-24-02-2017-Resolucion_2.pdf
# [242/295] OK   290490 bytes -> S-59-2017-20-02-2017-Resolucion_2.pdf
# [243/295] OK   274911 bytes -> S-58-2017-03-02-2017-Resolucion_2.pdf
# [244/295] OK   559272 bytes -> S-57-2017-04-01-2017-Resolucion_2.pdf
# [245/295] OK   276066 bytes -> S-56-2016_07-12-2016_Resolucion_2.pdf
# [246/295] OK   162581 bytes -> S-55-2016-29-12-2016-Resolucion_2.pdf
# [247/295] OK   426509 bytes -> S-54-2016-02-11-2016-Resolucion_2.pdf
# [248/295] OK   149907 bytes -> S-53-2016-28-10-2016-Resolucion_2.pdf
# [249/295] OK   180471 bytes -> S-52-2016-03-10-2016-Resolucion_2.pdf
# [250/295] OK   179360 bytes -> S-50-2016-28-09-2016-Resolucion_2.pdf
# [251/295] OK   159719 bytes -> S-49-2016-26-09-2016-Resolucion_2.pdf
# [252/295] OK   300942 bytes -> S-48-2016-01-09-2016-Resolucion_2.pdf
# [253/295] OK   138944 bytes -> S-47-2016-25-08-2016-Resolucion_2.pdf
# [254/295] OK   438644 bytes -> S-46-2016-26-08-2016-Resolucion_2.pdf
# [255/295] OK   209296 bytes -> S-45-2016-18-08-2016-Resolucion_2.pdf
# [256/295] OK   441821 bytes -> S-44-2016-29-07-2016-Resolución_2.pdf
# [257/295] OK   315471 bytes -> S-43-2016-27-07-2016-Resolucion_2.pdf
# [258/295] OK   165848 bytes -> S-42-2016-15-07-2016-Resolucion_2.pdf
# [259/295] OK   299199 bytes -> S-41-2016-14-07-2016-Resolucion_2.pdf
# [260/295] OK   124940 bytes -> S-40-2016-30-06-2016-Resolucion_2.pdf
# [261/295] OK   319565 bytes -> S-39-2016-28-06-2016-Resolucion_2.pdf
# [262/295] OK   122731 bytes -> S-38-2016-14-06-2016-Resolucion_2.pdf
# [263/295] OK   180178 bytes -> S-37-2016-31-05-2016-Resolucion_2.pdf
# [264/295] OK   337491 bytes -> S-36-2016-18-05-2016-Resolucion_2.pdf
# [265/295] OK   356845 bytes -> S-35-2016-13-05-2016-Resolucion_2.pdf
# [266/295] OK   45850 bytes -> S-34-2016-28-04-2016-Resolucion_2.pdf
# [267/295] OK   92566 bytes -> S-33-2016-26-04-2016-Resolucion-1_2.pdf
# [268/295] OK   63826 bytes -> S-32-2016-14-04-2016-Resolucion_2.pdf
# [269/295] OK   65996 bytes -> S-31-2016-22-03-2016-Resolucion_2.pdf
# [270/295] OK   165585 bytes -> S-30-2016-14-03-2016-Resolucion_2.pdf
# [271/295] OK   211051 bytes -> S-29-2016-03-03-2016-Resolucion_2.pdf
# [272/295] OK   93135 bytes -> S-28-2016-16-02-2016-Resolucion_2.pdf
# [273/295] OK   87810 bytes -> S-27-2016-12-02-2016-Resolucion_2.pdf
# [274/295] OK   58754 bytes -> S-26-2016-10-02-2016-Resolucion-SMA_2.pdf
# [275/295] OK   221624 bytes -> S-24-2016-25-01-2016-Resolucion_2.pdf
# [276/295] OK   274025 bytes -> S-23-2016-15-01-2016-Resolucion_2.pdf
# [277/295] OK   107322 bytes -> S-22-2015-21-04-2015-Resolucion_2.pdf
# [278/295] OK   96414 bytes -> S-21-2015-20-03-2015-Resolucion_2.pdf
# [279/295] OK   62474 bytes -> S-20-2015-03-03-2015-Resolucion_2.pdf
# [280/295] OK   79576 bytes -> S-18-2015-11-03-2015-Resolucion_2.pdf
# [281/295] OK   466990 bytes -> S-17-2015-13-02-2015-Resolucion_2.pdf
# [282/295] OK   60928 bytes -> S-16-2015-04-02-2015-Resolucion_2.pdf
# [283/295] OK   365366 bytes -> S-14-2015-09-01-2015-Resolucion_2.pdf
# [284/295] OK   336886 bytes -> S-13-2015-06-01-2015-Resolucion_2.pdf
# [285/295] OK   247810 bytes -> S-12-2014-10-12-2014-Resolucion_2.pdf
# [286/295] OK   170622 bytes -> S-11-2014-04-12-2014-Resolucion_2.pdf
# [287/295] OK   390953 bytes -> S-10-2014-04-12-2014-Resolucion_2.pdf
# [288/295] OK   322490 bytes -> S-09-2014_30-10-2014_Resolucion-Foliada_2.pdf
# [289/295] OK   122211 bytes -> S-08-2014-22-09-2014-Resolucion-Foliada_2.pdf
# [290/295] OK   71079 bytes -> S-06-2013-19-12-2013-Resolucion1_2.pdf
# [291/295] OK   42417 bytes -> S-05-2013-03-12-2013-Resolucion_2.pdf
# [292/295] OK   36802 bytes -> S-04-2013-12-11-2013-Resolucion_2.pdf
# [293/295] OK   46275 bytes -> S-03-2013-12-07-2013-Resolucion_2.pdf
# [294/295] OK   60588 bytes -> S-01-2013-25-06-2013-Resolucion_2.pdf
# [295/295] OK   229059 bytes -> 2021.08.06-RES-ADM-049-2021-CD-LS-firmada-1_2.pdf
#
# == Resumen ==
# OK: 294
# FAIL: 1
# Manifest: /content/tribunal_pdfs_manifest.csv
# PDFs en: /content/tribunal_pdfs

# %%
# Colab: crear ZIP con todos los PDFs + el manifest, y descargarlo

ZIP_PATH = "/content/tribunal_pdfs_bundle.zip"

# 1) Crear zip (incluye carpeta tribunal_pdfs y el manifest)
# !rm -f "$ZIP_PATH"
# !zip -r "$ZIP_PATH" /content/tribunal_pdfs /content/tribunal_pdfs_manifest.csv

# 2) Descargar al computador
from google.colab import files
files.download(ZIP_PATH)
# Out:
#   adding: content/tribunal_pdfs/ (stored 0%)
#   adding: content/tribunal_pdfs/S-16-2015-04-02-2015-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/CS_13177-2018_2TA_D-13-2014_Sentencia-reemplazo_2.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/D-17-2015-07-07-2017-Sentencia.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2024.11.04_Sentencia_R-454-2024_2.pdf (deflated 28%)
#   adding: content/tribunal_pdfs/2024.11.15_Sentencia_R-451-2024_2.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/2025.03.13_Sentencia_R-466-2024.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/2025.10.30_Sentencia_R-465-2024.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/Sentencia-de-reemplazo-Rol-37273-2017-Nogales.pdf (deflated 40%)
#   adding: content/tribunal_pdfs/S-53-2016-28-10-2016-Resolucion_2.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/2024.11.06_Sentencia_R-425-2023.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/2024.07.03_Sentencia_R-405-2023_2.pdf (deflated 28%)
#   adding: content/tribunal_pdfs/Sentencia-CS-acoge-casación-forma-caso-Inversiones-Las-Agatas-con-malhue-Gross-41417-2017-D-28-2016_2.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/2025.02.20_Sentencia_S-84-2025.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/2022.07.06_Sentencia_R-215-2019_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/1085-2022-Sentencia-de-reemplazo_2.pdf (deflated 37%)
#   adding: content/tribunal_pdfs/S-14-2015-09-01-2015-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2024.05.30_Sentencia_R-397-2023.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/S-54-2016-02-11-2016-Resolucion.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2022.11.24_Sentencia_R-315-2021.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2024.03.11_Sentencia_R-331-2022_2.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/D-25-2016-29-03-2018-Sentencia.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/R-279-2021_26-07-2023_Sentencia.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/2025.03.19_Sentencia_R-433-2023.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/R-334-2022_18-07-2023_Sentencia_2.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/S-33-2016-26-04-2016-Resolucion-1_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/Sentencia_CS_96002-2021_2TA_R-183-2018.pdf (deflated 50%)
#   adding: content/tribunal_pdfs/D-24-2016-Aguas-Andina.pdf (deflated 41%)
#   adding: content/tribunal_pdfs/2023.01.30_Sentencia_R_316-2021_acumulada_R_317-2021_2.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/2022.10.05_Sentencia_R-310_311-2021_2.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/Sentencia_R-210-2019_-_14.10.2020.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/S-33-2016-26-04-2016-Resolucion-1.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2023.12.07_Sentencia_R-360-2022_2.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/2023.11.20_Sentencia_R-350-2022.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/2023.07.10_Sentencia_R-384-2022.pdf (deflated 30%)
#   adding: content/tribunal_pdfs/2021.08.06-RES-ADM-049-2021-CD-LS-firmada-1_2.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/R-278-2021_24-02-2022_Sentencia_2.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/2022.12.19_Sentencia_R-319-2022-1.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/S-11-2014-04-12-2014-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/S-52-2016-03-10-2016-Resolucion_2.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/2025.03.27_Sentencia_R-456-2024.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/2025.03.19_Sentencia_R-434-2023_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2024.06.07_Sentencia_R-424-2023.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/S-12-2014-10-12-2014-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2022.06.28_Sentencia_R-232_y_276_2.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/S-68-2019-29-03-2019-Resolución.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2023.11.02_Sentencia_R-353-2022_2.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/R-234-2020_22-06-2021_Sentencia_2.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/Sentencia-Casacion_D-9-2014_Catemu.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/S-01-2013-25-06-2013-Resolucion_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/Sentencia_D-68-2022_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/S-79-2023_2.pdf (deflated 39%)
#   adding: content/tribunal_pdfs/2022.07.12_Sentencia_R-273-2021_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/D-06-2013-29-11-2014-Sentencia-Foliada.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/D-23-2016-11-05-2018-Sentencia.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2023.11.09_Sentencia_S-80-2023_2.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/S-17-2015-13-02-2015-Resolucion_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/S-23-2016-15-01-2016-Resolucion.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/Sentencia_R_237-2020-13.05.2021_2.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/Sentencia_R_231-2020-25.11.2021.pdf (deflated 28%)
#   adding: content/tribunal_pdfs/R-253-2020_13-07-2021_Sentencia_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/S-28-2016-16-02-2016-Resolucion.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/S-57-2017-04-01-2017-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2022.07.22_Sentencia_R-285-2021_2.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/Sentencia-Casacion_D-9-2014_Catemu_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/S-21-2015-20-03-2015-Resolucion.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/2023.09.06_Sentencia_R-349-2022_2.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/2024.02.09_Sentencia_R-343-2022_2.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/Sentencia_Rol_N_314-2021_002.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/S-17-2015-13-02-2015-Resolucion.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/Sentencia_R_231-2020-25.11.2021_2.pdf (deflated 28%)
#   adding: content/tribunal_pdfs/C-02-2013-11-11-2013-Sentencia-1_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2022.12.30_Sentencia_R-265-2020-1.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/2025.09.17_Sentencia_R-470-2024_2.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/D-28-2016-31-07-2017-Sentencia.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/D-26-2016-23-11-2018-Sentencia_2.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/R-45-2014-06-01-2015-Doc.-Informe-en-Derecho-Luis-Cordero-Vega..pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2022.12.19_Sentencia_R-319-2022-1_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/D-17-2015-07-07-2017-Sentencia_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2024.09.16_Sentencia_R-435-2023_2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/S-22-2015-21-04-2015-Resolucion.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/R-356-2022_26-07-2023_Sentencia.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/2024.07.03_Sentencia_R-413-2023.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/2025.02.11_Sentencia_R-346-2022.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/2025.04.17_Sentencia_R-458-2024_2.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/Sentencia_R-371-2022_2.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/2022.09.06_Sentencia_R-326-2022.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/2023.11.09_Sentencia_S-80-2023.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/S-67-2019-01-03-2019-Resolución_2.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/2025.09.30_Sentencia_R-522-2025.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Gabriel-Del-Favero-Valdes_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/S-66-2018-31-08-2018-Resolución.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/Sentencia_R-322-2022_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2025.03.19_Sentencia_R-433-2023_2.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/R-233-2020_18-06-2021_Sentencia.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/D-26-2016-23-11-2018-Sentencia.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/2024.04.26_Sentencia_R-400-2023.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/S-50-2016-28-09-2016-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2025.05.29_Sentencia_R-479-2024_2.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/D-14-2014-24-08-2016-Sentencia_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/D-14-2014-24-08-2016-Sentencia.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/Sentencia-D-32-2016_2.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/S-22-2015-21-04-2015-Resolucion_2.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/Sentencia_R_N_240-2020.-1_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2025.02.20_Sentencia_S-84-2025_2.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/S-43-2016-27-07-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2025.09.30_Sentencia_R-522-2025_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/R-244-2020_25-05-2022_Sentencia.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2022.09.06_Sentencia_R-326-2022_2.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/R-340-2022_16-03-2023_Sentencia.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/2024.04.22_Sentencia_R-396-2023.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/2022.11.09_Sentencia_R_295-2021.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/S-37-2016-31-05-2016-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2024.05.27_Sentencia_R-407-2023.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/C-3-2014_29-01-2015_Resolucion_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/2025.08.29_Sentencia_R-453-2024_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/R-267-2020_12-09-2022_Sentencia.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/R-16-2013-Informe-Alejandro-Romero-Sequel_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2023.06.30_Sentencia_R-282-2021_acumulada_R-303-2021_2.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/S-58-2017-03-02-2017-Resolucion_2.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/2024.04.24_Sentencia_R-383-2022.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/R-07-2013-Informe-en-derecho-de-don-Alejandro-Romero-Seguel1_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/Sentencia_R-221-2019_2.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/S-41-2016-14-07-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/Candelaria-Casacion.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/2025.10.02_Sentencia_R-482-2024_2.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Rodrigo-Silva-Montes1.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2025.10.09_Sentencia_R-327-2022_R328_R335_R337_R338_R447_2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/S-78-2023.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/2024.07.17_Sentencia_R-440-2023.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/S-43-2016-27-07-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2022.08.24_Sentencia_R-261-2020_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/Candelaria-Casacion_2.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/S-10-2014-04-12-2014-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/CS_13177-2018_2TA_D-13-2014_Sentencia_2.pdf (deflated 36%)
#   adding: content/tribunal_pdfs/2022.11.21_Sentencia_R-339-2022-2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/2023.01.30_Sentencia_R-289-290__2.pdf (deflated 14%)
#   adding: content/tribunal_pdfs/Sentencia_R-392-2023.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/2024.11.07_Sentencia_R-428-2023.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/S-34-2016-28-04-2016-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2022.06.28_Sentencia_R-232_y_276.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/2022.11.21_Sentencia_R-339-2022-2_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/D-27-2016-22-11-2018-Sentencia.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2025.07.07_Sentencia_R-463-2024_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/S-61-2017-07-03-2017-Resolucion.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/R-279-2021_26-07-2023_Sentencia_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/S-27-2016-12-02-2016-Resolucion_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/S-40-2016-30-06-2016-Resolucion_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2024.06.07_Sentencia_R-424-2023_2.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/2022.12.02_Sentencia_R-341-2022.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/Rol-N_-22.343-2021-casacion_2.pdf (deflated 38%)
#   adding: content/tribunal_pdfs/2023.07.10_Sentencia_R-384-2022_2.pdf (deflated 30%)
#   adding: content/tribunal_pdfs/2025.08.19_Sentencia_R-375-2022_y_acumuladas-1_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/CS_13177-2018_2TA_D-13-2014_Sentencia-reemplazo.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/2024.03.28_Sentencia_D-78-2022.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2024.04.15_Sentencia_R-409-2023.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/S-39-2016-28-06-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2024.04.26_Sentencia_R-400-2023_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/C-02-2013-29-07-2013-Sentencia.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/Sentencia_D-68-2022.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2024.07.17_Sentencia_R-443-2023.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/2024.08.14_Sentencia_R-412-2023.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/S-40-2016-30-06-2016-Resolucion.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/S-79-2023.pdf (deflated 39%)
#   adding: content/tribunal_pdfs/2025.08.29_Sentencia_R-483-2024_2.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/S-14-2015-09-01-2015-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/D-03-2013-10-04-2015-Sentencia-foliada.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/R-267-2020_12-09-2022_Sentencia_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2023.12.15_Sentencia_S-81-2023.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/S-12-2014-10-12-2014-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-44-2016-29-07-2016-Resolución_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/R-243-2020_14-10-2021_Sentencia_2.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/Sentencia_R-324-2022-1_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/R-224-2019_17-06-2021_Sentencia.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/S-16-2015-04-02-2015-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/5.374-2021-reemplazo.pdf (deflated 40%)
#   adding: content/tribunal_pdfs/R-40-Opinion-Legal-Cristian-Maturana.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/S-56-2016_07-12-2016_Resolucion_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/2024.07.17_Sentencia_R-408-2023.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/D-09-2014-26-01-2015-Sentencia.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/2023.10.19_Sentencia_R-395-2023.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/S-45-2016-18-08-2016-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/D-03-2013-10-04-2015-Sentencia-foliada_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/R-354-2022_19-07-2023_Sentencia_2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/CS_13177-2018_2TA_D-13-2014_Sentencia.pdf (deflated 36%)
#   adding: content/tribunal_pdfs/2024.02.26_Sentencia_R-271_270-2020_2.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/Sentencia_R-210-2019_-_14.10.2020_2.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/D-28-2016-31-07-2017-Sentencia_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2025.02.19_Sentencia_R427-2023_R_431-2023_2.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/S-29-2016-03-03-2016-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2024.11.06_Sentencia_R-425-2023_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/2022.07.20_Sentencia_R-263-2020.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2024.04.26_Sentencia_R-399-2023.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/2023.05.11_Sentencia_R-342-2022_2.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/Sentencia_Corte-Suprema_Rol-31.124-2021_2TA_D-37-2017_2.pdf (deflated 49%)
#   adding: content/tribunal_pdfs/R-308-2021_2.pdf (deflated 64%)
#   adding: content/tribunal_pdfs/S-46-2016-26-08-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/R-398-2023-aprueba-concilacion.pdf (deflated 57%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Gabriel-Del-Favero-Valdes.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2022.10.26_Sentencia_R-304-2021acum.R325-2022_2.pdf (deflated 36%)
#   adding: content/tribunal_pdfs/R-220-2019_30-03-2021_Sentencia_2.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/2022.11.02_Sentencia_R-307-2021_2.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/S-35-2016-13-05-2016-Resolucion.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/Sentencia_CS_96002-2021_2TA_R-183-2018_2.pdf (deflated 50%)
#   adding: content/tribunal_pdfs/SCS-rol-34697-2021.-Tapia-Azocar-con-SMA.-Acoge-casacion.pdf (deflated 37%)
#   adding: content/tribunal_pdfs/2023.12.20_Sentencia_R-370-2022_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/R-305-2021_16-12-2022_Sentencia_foliada-2_2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/2025.03.19_Sentencia_R-434-2023.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Luis-Cordero-Vega_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/S-57-2017-04-01-2017-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2025.09.15_Sentencia_R-504-2025_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/S-58-2017-03-02-2017-Resolucion.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/SCS.-154847-2020.-Maturana-con-SEA.-R-178-2018_2.pdf (deflated 56%)
#   adding: content/tribunal_pdfs/Rol-N_-22.343-2021-reemplazo.pdf (deflated 50%)
#   adding: content/tribunal_pdfs/S-37-2016-31-05-2016-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2024.11.07_Sentencia_R-428-2023_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/D-24-2016-27-04-2017-Sentencia_2.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/S-08-2014-22-09-2014-Resolucion-Foliada_2.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/Informe-en-derecho-concurso-infraccional-imperfecto-Jean-Pierre-Matus_2.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/Sentencia-CS-15247_2018_D-23-2016.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/S-30-2016-14-03-2016-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/R-277-2021_30-12-2022_Sentencia-4_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/R-183-2018_03-11-2021_Sentencia.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/S-18-2015-11-03-2015-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2025.03.25_Sentencia_S-85-2025_2.pdf (deflated 31%)
#   adding: content/tribunal_pdfs/S-05-2013-03-12-2013-Resolucion_2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/R-310-2022_CS.pdf (deflated 54%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Luis-Cordero-Vega.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/Informe-en-derecho-concurso-infraccional-imperfecto-Jean-Pierre-Matus.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/2024.05.30_Sentencia_R-397-2023_2.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/S-55-2016-29-12-2016-Resolucion_2.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/2023.10.11_Sentencia_R-376-2022_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2024.07.17_Sentencia_R-408-2023_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/2022.12.30_Sentencia_R-265-2020-1_2.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/S-11-2014-04-12-2014-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2025.10.30_Sentencia_R-465-2024_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/R-40-Informe-en-Derecho-Andres-Bordali.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/2024.05.27_Sentencia_R-418-2023_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2025.07.03_Sentencia_R-459-2024_2.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/S-44-2016-29-07-2016-Resolución.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2023.10.25_Sentencia_R-378-2022.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/2024.04.22_Sentencia_R-404-2023.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/C-02-2013-11-11-2013-Sentencia-1.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/R-06-2013_Informe_en_Derecho_Sr-Patricio-Leyton-Florez.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/2024.05.31_Sentencia_R-432-2023_2.pdf (deflated 14%)
#   adding: content/tribunal_pdfs/D-25-2016-29-03-2018-Sentencia_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/S-46-2016-26-08-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/R-340-2022_16-03-2023_Sentencia_2.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/2024.01.26_Sentencia_Rol-348-2022.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/S-32-2016-14-04-2016-Resolucion.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/2024.02.09_Sentencia_R-343-2022.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/R-277-2021_30-12-2022_Sentencia-4.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/R-310-2022_CS_2.pdf (deflated 54%)
#   adding: content/tribunal_pdfs/2024.05.31_Sentencia_R-432-2023.pdf (deflated 14%)
#   adding: content/tribunal_pdfs/2025.07.07_Sentencia_R-463-2024.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2025.03.25_Sentencia_S-85-2025.pdf (deflated 31%)
#   adding: content/tribunal_pdfs/R-318-2021_26-09-2022_Sentencia_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/2023.08.23_Sentencia_R-388-2023_2.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/Sentencia_Corte_Suprema_Rol_1583-2019_2TA_D-26-2016.pdf (deflated 49%)
#   adding: content/tribunal_pdfs/R-236-2020_01-10-2021_Sentencia_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/Candelaria-Reemplazo.pdf (deflated 41%)
#   adding: content/tribunal_pdfs/2023.08.08_Sentencia_R-281-2021.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/R-251-2020_09-08-2021_Sentencia_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2023.08.22_Sentencia_R-363-2023_2.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/Sentencia_R-324-2022-1.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/R-269-2020_28-02-2022_Sentencia_foliada_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/R-251-2020_09-08-2021_Sentencia.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/Sentencia_R_219-2019-05-04-2021.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/Sentencia_Corte_Suprema_Rol_27726-2019_2TA_D-27-2016.pdf (deflated 49%)
#   adding: content/tribunal_pdfs/Sentencia_Corte-Suprema_Rol-31.124-2021_2TA_D-37-2017.pdf (deflated 49%)
#   adding: content/tribunal_pdfs/Sentencia_R_208-2019-14.04.2021.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/2023.06.30_Sentencia_R-282-2021_acumulada_R-303-2021.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/R-315-2022-CS_2.pdf (deflated 56%)
#   adding: content/tribunal_pdfs/C-02-2013-29-07-2013-Sentencia_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/Sentencia_Rol_N_314-2021_002_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/S-65-2018-27-06-2018-Resolución.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2025.08.25_Sentencia_R-506-2025.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/2022.10.05_Sentencia_R-310_311-2021.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/2024.03.19_Sentencia_R-264-2020.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/S-59-2017-20-02-2017-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2022.12.02_Sentencia_R-341-2022_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/5.374-2021-reemplazo_2.pdf (deflated 40%)
#   adding: content/tribunal_pdfs/2022.11.30_Sentencia_R-283-2021_2.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/2025.12.05_Sentencia_R-481-2024_.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2021.08.06-RES-ADM-049-2021-CD-LS-firmada-1.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/R-207-2919_Rol-Corte-Suprema_18.996-2021_2.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/R-207-2919_Rol-Corte-Suprema_18.996-2021.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/R-266-2020_19-12-2022_Sentencia_foliada.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/S-65-2018-27-06-2018-Resolución_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/S-45-2016-18-08-2016-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/Sentencia_R_208-2019-14.04.2021_2.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/S-01-2013-25-06-2013-Resolucion.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/S-63-2017-18-04-2017-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/S-50-2016-28-09-2016-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2023.08.10_Sentencia_R-292-2021.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/Sentencia_R_426-2023_2.pdf (deflated 44%)
#   adding: content/tribunal_pdfs/R-354-2022_19-07-2023_Sentencia.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/S-09-2014_30-10-2014_Resolucion-Foliada_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2025.06.03_Sentencia_R-347-2022_acumulada_R-439-2023_2.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/S-31-2016-22-03-2016-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/5.374-2021-casacion.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/2024.05.27_Sentencia_R-418-2023.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Jorge-Bermudez-Soto.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/R-334-2022_18-07-2023_Sentencia.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/R-40-Informe-en-Derecho-Cristian-Maturana-y-Jaime-Jara_2.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/2025.03.13_Sentencia_R-466-2024_2.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/S-04-2013-12-11-2013-Resolucion_2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/R-252-2020_19-11-2021_Sentencia.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/Sentencia_CS-60804-2021_2TA_D-36-2017-1.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/S-05-2013-03-12-2013-Resolucion.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/2024-12-27_Sentencia_D-71-2022.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/S-54-2016-02-11-2016-Resolucion_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/R-269-2020_28-02-2022_Sentencia_foliada.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/S-06-2013-19-12-2013-Resolucion1.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/R-239-2020_14-07-2021_Sentencia_2.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/S-82-2024-1_2.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/Sentencia_CS_58263-2021_2TA_R-238-2020.pdf (deflated 41%)
#   adding: content/tribunal_pdfs/C-04-2015-08-09-2015-Sentencia_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/Rol-N_-22.343-2021-casacion.pdf (deflated 38%)
#   adding: content/tribunal_pdfs/2022.07.25_Sentencia_R-293-2021__2.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/R-253-2020_13-07-2021_Sentencia.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/S-04-2013-12-11-2013-Resolucion.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/2023.10.19_Sentencia_R-395-2023_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/S-60-2017-24-02-2017-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2023.04.19_Sentencia_R-313-2021_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/R-224-2019_17-06-2021_Sentencia_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2023.08.08_Sentencia_R-281-2021_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/1085-2022-Casacion.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/2022.08.24_Sentencia_R-261-2020.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/2024.04.24_Sentencia_R-374-2022_2.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/2023.11.20_Sentencia_R-350-2022_2.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/R-220-2019_30-03-2021_Sentencia.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/Sentencia-CS-Inmobiliaria-Laderas-Ladomar-S.A.-con-SMA.pdf (deflated 50%)
#   adding: content/tribunal_pdfs/R-40-Informe-en-Derecho-Cristian-Maturana-y-Jaime-Jara.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/2024.04.22_Sentencia_R-396-2023_2.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/C-06-2016-13-07-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/1085-2022-Casacion_2.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/2023.01.30_Sentencia_R-301-2021_acumulada_R-309-202133131_2.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/R-398-2023-aprueba-concilacion_2.pdf (deflated 57%)
#   adding: content/tribunal_pdfs/R-266-2020_19-12-2022_Sentencia_foliada_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/S-66-2018-31-08-2018-Resolución_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2023.09.06_Sentencia_R-349-2022.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/S-03-2013-12-07-2013-Resolucion_2.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/Sentencia_Corte-Suprema_79079-2020_2TA-D-39-2017.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/S-55-2016-29-12-2016-Resolucion.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/Sentencia_Corte-Suprema_6960-2021-R-200-2018-STA_2.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/Sentencia_CS-60804-2021_2TA_D-36-2017-1_2.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/2023.12.20_Sentencia_R-370-2022.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/Sentencia-casación-Rol-37273-2017-Nogales_2.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/2023.01.30_Sentencia_R-289-290_.pdf (deflated 14%)
#   adding: content/tribunal_pdfs/S-09-2014_30-10-2014_Resolucion-Foliada.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2023.12.15_Sentencia_S-81-2023_2.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/SCS.-154847-2020.-Maturana-con-SEA.-R-178-2018.pdf (deflated 56%)
#   adding: content/tribunal_pdfs/2023.05.11_Sentencia_R-342-2022.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/2023.09.13_Sentencia_R-373-2022_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/2024.04.11_Sentencia_R-403-2023-1.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/2024-12-16_Sentencia_D-74-2022.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/S-78-2023_2.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/S-48-2016-01-09-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-60-2017-24-02-2017-Resolucion.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/S-30-2016-14-03-2016-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2024.07.03_Sentencia_R-405-2023.pdf (deflated 28%)
#   adding: content/tribunal_pdfs/D-15-2015-06-01-2017-Sentencia.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/S-48-2016-01-09-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2023.10.12_Sentencia_R-323-2022.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2025.02.11_Sentencia_R-346-2022_2.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/2024.08.27_Sentencia_R-414-2023.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/2024.06.28_Sentencia_R-377-2023.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2022.07.12_Sentencia_R-273-2021.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/Sentencia-CS-Inmobiliaria-Laderas-Ladomar-S.A.-con-SMA_2.pdf (deflated 50%)
#   adding: content/tribunal_pdfs/2025.09.17_Sentencia_R-470-2024.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/S-47-2016-25-08-2016-Resolucion_2.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/2023.08.10_Sentencia_R-292-2021_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/1085-2022-Sentencia-de-reemplazo.pdf (deflated 37%)
#   adding: content/tribunal_pdfs/R-252-2020_19-11-2021_Sentencia_2.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/S-31-2016-22-03-2016-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2023.08.23_Sentencia_R-388-2023.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/Sentencia_CS_58263-2021_2TA_R-238-2020_2.pdf (deflated 41%)
#   adding: content/tribunal_pdfs/2023.11.02_Sentencia_R-353-2022.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/S-34-2016-28-04-2016-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2022.10.26_Sentencia_R-304-2021acum.R325-2022.pdf (deflated 36%)
#   adding: content/tribunal_pdfs/Informe_en_derecho-_Terceros_Coadyuvantes_en_Casacion-_A-Romero-Seguel_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/D-36-2017-28-06-2018-Sentencia_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/R-315-2022-CS.pdf (deflated 56%)
#   adding: content/tribunal_pdfs/S-68-2019-29-03-2019-Resolución_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/Informe_en_derecho-_Terceros_Coadyuvantes_en_Casacion-_A-Romero-Seguel.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/S-83-2024.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/R-16-2013-Informe-Alejandro-Romero-Sequel.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2024-12-16_Sentencia_D-74-2022_2.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/S-82-2024-1.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/S-26-2016-10-02-2016-Resolucion-SMA.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/Sentencia_R-221-2019.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/Sentencia-casación-Rol-37273-2017-Nogales.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/S-67-2019-01-03-2019-Resolución.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/2023.04.25_Sentencia_R-280-2021.pdf (deflated 30%)
#   adding: content/tribunal_pdfs/Sentencia-D-32-2016.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/D-09-2014-26-01-2015-Sentencia_2.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/2025.10.09_Sentencia_R-327-2022_R328_R335_R337_R338_R447.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/R-244-2020_25-05-2022_Sentencia_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2025.04.11_Sentencia_S-86-2025_2.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/Sentencia_R_352-2022.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/D-13-2014-13-03-2018-Sentencia.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Rodrigo-Silva-Montes1_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/R-234-2020_22-06-2021_Sentencia.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/S-56-2016_07-12-2016_Resolucion.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/S-59-2017-20-02-2017-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/S-62-2017-06-04-2017-Resolucion_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/S-29-2016-03-03-2016-Resolucion_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/R-40-2014-Informe-en-Derecho-Claudio-Moraga.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/S-83-2024_2.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/R-230-2020_10-03-2022_Sentencia_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/D-24-2016-Aguas-Andina_2.pdf (deflated 41%)
#   adding: content/tribunal_pdfs/SCS-rol-34697-2021.-Tapia-Azocar-con-SMA.-Sentencia-de-Reemplazo_2.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/2024.04.24_Sentencia_R-383-2022_2.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/S-36-2016-18-05-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-13-2015-06-01-2015-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2025.04.17_Sentencia_R-458-2024.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/2024.11.04_Sentencia_R-454-2024.pdf (deflated 28%)
#   adding: content/tribunal_pdfs/2024.10.29_Sentencia_R-406-2023.pdf (deflated 48%)
#   adding: content/tribunal_pdfs/Sentencia_R_226-2020-09.04.2021.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2024.04.30_Sentencia_R-379-2022.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/C-06-2016-13-07-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2024.06.28_Sentencia_R-377-2023_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2022.07.06_Sentencia_R-215-2019.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/R-230-2020_10-03-2022_Sentencia.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/R-239-2020_14-07-2021_Sentencia.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/S-03-2013-12-07-2013-Resolucion.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/C-01-2013-29-07-2013-Sentencia.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/R-06-2013-Informe-en-derecho-de-don-Jorge-Bermudez-Soto_2.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/2024.03.19_Sentencia_R-264-2020_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2024.01.26_Sentencia_Rol-348-2022_2.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/D-06-2013-29-11-2014-Sentencia-Foliada_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2023.01.30_Sentencia_R_316-2021_acumulada_R_317-2021.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/S-49-2016-26-09-2016-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/S-24-2016-25-01-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-28-2016-16-02-2016-Resolucion_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2024.04.08_Sentencia_R-385-2023_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/2022.10.24_Sentencia_R-297-298-299.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/2025.07.03_Sentencia_R-459-2024.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/R-362-2022_19-07-2023_Sentencia_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/Sentencia-CS-15247_2018_D-23-2016_2.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/2024.04.30_Sentencia_R-379-2022_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/2024.04.26_Sentencia_R-399-2023_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/S-77-2023_2.pdf (deflated 39%)
#   adding: content/tribunal_pdfs/2024.08.22_Sentencia_R-417-2023_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/Sentencia_CS_82391-2021_2TA_R-262-2020_2.pdf (deflated 44%)
#   adding: content/tribunal_pdfs/2024.10.29_Sentencia_R-406-2023_2.pdf (deflated 48%)
#   adding: content/tribunal_pdfs/S-39-2016-28-06-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/R-45-2014-06-01-2015-Doc.-Informe-en-Derecho-Luis-Cordero-Vega._2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/R-40-2014-Informe-en-Derecho-Claudio-Moraga_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/2024.03.11_Sentencia_R-331-2022.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/D-02-2013-20-03-2015-Sentencia_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/S-63-2017-18-04-2017-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/S-20-2015-03-03-2015-Resolucion_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2022.11.24_Sentencia_R-315-2021_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/R-238-2020_16-06-2021_Sentencia.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2025.09.15_Sentencia_R-504-2025.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/Sentencia_Corte-Suprema_6960-2021-R-200-2018-STA.pdf (deflated 43%)
#   adding: content/tribunal_pdfs/R-305-2021_16-12-2022_Sentencia_foliada-2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/Sentencia_R_352-2022_2.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/2024.12.23_Sentencia_R-450-2024_2.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/Reemplazo-caso-Inversiones-Las-Agatas-con-Malhue-Gross-Rol-41417-2017-D28-2016_2.pdf (deflated 36%)
#   adding: content/tribunal_pdfs/2022.11.02_Sentencia_R-307-2021.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/R-238-2020_16-06-2021_Sentencia_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2024.11.15_Sentencia_R-451-2024.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/2022.11.30_Sentencia_R-283-2021.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/S-24-2016-25-01-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2024.04.11_Sentencia_R-403-2023-1_2.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/S-42-2016-15-07-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/R-236-2020_01-10-2021_Sentencia.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/S-32-2016-14-04-2016-Resolucion_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/2024.05.27_Sentencia_R-407-2023_2.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/Candelaria-Reemplazo_2.pdf (deflated 41%)
#   adding: content/tribunal_pdfs/D-23-2016-11-05-2018-Sentencia_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/S-64-2018-17-04-2018-Resolución.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/D-24-2016-27-04-2017-Sentencia.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/R-262-2020_12-08-2021_Sentencia_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/2023.08.22_Sentencia_R-363-2023.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/2024.08.14_Sentencia_R-412-2023_2.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/2024.09.16_Sentencia_R-435-2023.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/2024.04.15_Sentencia_R-409-2023_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/2025.10.02_Sentencia_R-482-2024.pdf (deflated 21%)
#   adding: content/tribunal_pdfs/S-36-2016-18-05-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-23-2016-15-01-2016-Resolucion_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/Sentencia-CS-acoge-casación-forma-caso-Inversiones-Las-Agatas-con-malhue-Gross-41417-2017-D-28-2016.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/R-40-Informe-en-Derecho-Andres-Bordali_2.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/2025.03.27_Sentencia_R-456-2024_2.pdf (deflated 15%)
#   adding: content/tribunal_pdfs/S-27-2016-12-02-2016-Resolucion.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/S-49-2016-26-09-2016-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2022.07.22_Sentencia_R-285-2021.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/R-233-2020_18-06-2021_Sentencia_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/Sentencia_R-392-2023_2.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/S-77-2023.pdf (deflated 39%)
#   adding: content/tribunal_pdfs/R-243-2020_14-10-2021_Sentencia.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/R-308-2021.pdf (deflated 64%)
#   adding: content/tribunal_pdfs/2024.04.08_Sentencia_R-385-2023.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/R-356-2022_26-07-2023_Sentencia_2.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/Sentencia_R-333-2022.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/Sentencia_Corte-Suprema_79079-2020_2TA-D-39-2017_2.pdf (deflated 35%)
#   adding: content/tribunal_pdfs/S-38-2016-14-06-2016-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2024.07.17_Sentencia_R-443-2023_2.pdf (deflated 24%)
#   adding: content/tribunal_pdfs/2024.04.22_Sentencia_R-404-2023_2.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/R-278-2021_24-02-2022_Sentencia.pdf (deflated 12%)
#   adding: content/tribunal_pdfs/R-06-2013_Informe_en_Derecho_Sr-Patricio-Leyton-Florez_2.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/2024.04.24_Sentencia_R-374-2022.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/Rol-N_-22.343-2021-reemplazo_2.pdf (deflated 50%)
#   adding: content/tribunal_pdfs/D-02-2013-20-03-2015-Sentencia.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/S-38-2016-14-06-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/Sentencia_R_426-2023.pdf (deflated 44%)
#   adding: content/tribunal_pdfs/2023.01.30_Sentencia_R-301-2021_acumulada_R-309-202133131.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/2025.02.19_Sentencia_R427-2023_R_431-2023.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/2025.08.25_Sentencia_R-506-2025_2.pdf (deflated 23%)
#   adding: content/tribunal_pdfs/S-26-2016-10-02-2016-Resolucion-SMA_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/C-04-2015-08-09-2015-Sentencia.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/2024.07.03_Sentencia_R-413-2023_2.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/Sentencia_Corte_Suprema_Rol_1583-2019_2TA_D-26-2016_2.pdf (deflated 49%)
#   adding: content/tribunal_pdfs/2022.07.25_Sentencia_R-293-2021_.pdf (deflated 34%)
#   adding: content/tribunal_pdfs/D-15-2015-06-01-2017-Sentencia_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/Reemplazo-caso-Inversiones-Las-Agatas-con-Malhue-Gross-Rol-41417-2017-D28-2016.pdf (deflated 36%)
#   adding: content/tribunal_pdfs/Sentencia_Corte_Suprema_Rol_27726-2019_2TA_D-27-2016_2.pdf (deflated 49%)
#   adding: content/tribunal_pdfs/S-21-2015-20-03-2015-Resolucion_2.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/S-47-2016-25-08-2016-Resolucion.pdf (deflated 3%)
#   adding: content/tribunal_pdfs/2024.07.17_Sentencia_R-440-2023_2.pdf (deflated 25%)
#   adding: content/tribunal_pdfs/S-53-2016-28-10-2016-Resolucion.pdf (deflated 8%)
#   adding: content/tribunal_pdfs/S-64-2018-17-04-2018-Resolución_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2022.11.09_Sentencia_R_295-2021_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/S-42-2016-15-07-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-61-2017-07-03-2017-Resolucion_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/S-62-2017-06-04-2017-Resolucion.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/2022.10.24_Sentencia_R-297-298-299_2.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/D-27-2016-22-11-2018-Sentencia_2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2024-12-27_Sentencia_D-71-2022_2.pdf (deflated 13%)
#   adding: content/tribunal_pdfs/2022.02.24_Sentencia_R-344-2022-1.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/R-40-Opinion-Legal-Cristian-Maturana_2.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/2025.04.11_Sentencia_S-86-2025.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/Sentencia_R-371-2022.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/S-41-2016-14-07-2016-Resolucion.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-08-2014-22-09-2014-Resolucion-Foliada.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/Sentencia_R_219-2019-05-04-2021_2.pdf (deflated 9%)
#   adding: content/tribunal_pdfs/2023.08.17_Sentencia_R-355-2022.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/2025.06.03_Sentencia_R-347-2022_acumulada_R-439-2023.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/2023.10.25_Sentencia_R-378-2022_2.pdf (deflated 27%)
#   adding: content/tribunal_pdfs/2023.12.07_Sentencia_R-360-2022.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/2024.12.23_Sentencia_R-450-2024.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/2024.02.26_Sentencia_R-271_270-2020.pdf (deflated 29%)
#   adding: content/tribunal_pdfs/2022.02.24_Sentencia_R-344-2022-1_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2022.07.20_Sentencia_R-263-2020_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/Sentencia_R_237-2020-13.05.2021.pdf (deflated 11%)
#   adding: content/tribunal_pdfs/2024.03.28_Sentencia_D-78-2022_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2023.10.11_Sentencia_R-376-2022.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/2023.10.12_Sentencia_R-323-2022_2.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/2023.08.17_Sentencia_R-355-2022_2.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/C-01-2013-29-07-2013-Sentencia_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/Sentencia_R_226-2020-09.04.2021_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2025.05.16_Sentencia_R-464-2024_2.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/Sentencia_R-322-2022.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/D-36-2017-28-06-2018-Sentencia.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2023.09.13_Sentencia_R-373-2022.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/2023.04.19_Sentencia_R-313-2021.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/R-262-2020_12-08-2021_Sentencia.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/S-35-2016-13-05-2016-Resolucion_2.pdf (deflated 0%)
#   adding: content/tribunal_pdfs/2025.08.29_Sentencia_R-483-2024.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/SCS-rol-34697-2021.-Tapia-Azocar-con-SMA.-Acoge-casacion_2.pdf (deflated 37%)
#   adding: content/tribunal_pdfs/D-13-2014-13-03-2018-Sentencia_2.pdf (deflated 5%)
#   adding: content/tribunal_pdfs/R-07-2013-Informe-en-derecho-de-don-Alejandro-Romero-Seguel1.pdf (deflated 2%)
#   adding: content/tribunal_pdfs/Sentencia-de-reemplazo-Rol-37273-2017-Nogales_2.pdf (deflated 40%)
#   adding: content/tribunal_pdfs/S-13-2015-06-01-2015-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/S-10-2014-04-12-2014-Resolucion_2.pdf (deflated 1%)
#   adding: content/tribunal_pdfs/Sentencia_R_N_240-2020.-1.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/C-3-2014_29-01-2015_Resolucion.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/S-52-2016-03-10-2016-Resolucion.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/Sentencia_CS_82391-2021_2TA_R-262-2020.pdf (deflated 44%)
#   adding: content/tribunal_pdfs/2025.08.19_Sentencia_R-375-2022_y_acumuladas-1.pdf (deflated 20%)
#   adding: content/tribunal_pdfs/S-18-2015-11-03-2015-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/5.374-2021-casacion_2.pdf (deflated 32%)
#   adding: content/tribunal_pdfs/Sentencia_R-333-2022_2.pdf (deflated 19%)
#   adding: content/tribunal_pdfs/R-362-2022_19-07-2023_Sentencia.pdf (deflated 16%)
#   adding: content/tribunal_pdfs/S-20-2015-03-03-2015-Resolucion.pdf (deflated 6%)
#   adding: content/tribunal_pdfs/2025.08.29_Sentencia_R-453-2024.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/S-06-2013-19-12-2013-Resolucion1_2.pdf (deflated 10%)
#   adding: content/tribunal_pdfs/2024.08.27_Sentencia_R-414-2023_2.pdf (deflated 17%)
#   adding: content/tribunal_pdfs/2024.08.22_Sentencia_R-417-2023.pdf (deflated 22%)
#   adding: content/tribunal_pdfs/SCS-rol-34697-2021.-Tapia-Azocar-con-SMA.-Sentencia-de-Reemplazo.pdf (deflated 42%)
#   adding: content/tribunal_pdfs/2025.12.05_Sentencia_R-481-2024__2.pdf (deflated 4%)
#   adding: content/tribunal_pdfs/2023.04.25_Sentencia_R-280-2021_2.pdf (deflated 30%)
#   adding: content/tribunal_pdfs/2025.05.16_Sentencia_R-464-2024.pdf (deflated 18%)
#   adding: content/tribunal_pdfs/R-183-2018_03-11-2021_Sentencia_2.pdf (deflated 7%)
#   adding: content/tribunal_pdfs/2025.05.29_Sentencia_R-479-2024.pdf (deflated 26%)
#   adding: content/tribunal_pdfs/R-318-2021_26-09-2022_Sentencia.pdf (deflated 16%)
#   adding: content/tribunal_pdfs_manifest.csv (deflated 91%)
